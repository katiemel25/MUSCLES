# %%
from __future__ import print_function
from scipy.optimize import curve_fit

import matplotlib.pyplot as plt
import numpy as np

#import astropy.io.fits as pyfits
import pyfits, time, itertools, random, os, sys, glob, re

from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=12, usetex=True)
#import seaborn as sns; sns.set()

# %matplotlib inline

# %% [markdown]
# ## Multiple Stars, Average Spectra (Updated June 5th)

# %%
star_names = np.genfromtxt("star_names.txt", dtype='str')

short_stars_rv = np.genfromtxt("RVs.txt", usecols=1, skip_header=2)
short_stars_photometry = np.loadtxt("photometry.txt")
#print(short_stars_rv)

#with open ("noisy_spectra.txt", "r") as myfile:
    #noisy=myfile.readlines()
#print(noisy)

# %%
stars_S_avgs = []
stars_S_avgs_err = []
stars_RHK_PRIME_avgs = []
stars_RHK_PRIME_avgs_err = []
log_stars_S_avgs = []
log_stars_S_avgs_err = []
log_stars_RHK_PRIME_avgs = []
log_stars_RHK_PRIME_avgs_err = []

#star_names = ["G80-21"]
#star_names = ["2MASSJ04184702+1321585"]
#star_names = ["2MASSJ03315564-4359135"]
#star_names = ["HD173739"]
#star_names = ["GJ176"]

for j in range(len(star_names)):
    print(star_names[j])
    
    #calculating stellar ccf (Astudillo-Defru 2017 equation 9 and table 1)
    #ALL COEFFS ARE FOR V-K COLOR
    ccf_c0 = -0.005
    ccf_c1 = 0.071
    ccf_c2 = -0.713 # +/- 0.006
    ccf_c3 = 0.973 # +/- 0.006
    
    R_c0 = -0.003
    R_c1 = 0.069
    R_c2 = -0.717 # +/- 0.003
    R_c3 = -3.498 # +/- 0.004
    
    V = short_stars_photometry[j][2]
    V_err = short_stars_photometry[j][3]
    K = short_stars_photometry[j][0]
    K_err = short_stars_photometry[j][1]
    V_K = V-K
    
    if (V-K < 1.45 or V-K > 6.73):
        print("V-K out of valid spectral range: ", V-K)
    
    ccf_rms = 0.0088
    R_rms = 3.0*10**-7

    #QUESTION: should "log" in the paper mean natural log???
    Ccf = 10**(ccf_c0*(V_K)**3 + ccf_c1*(V_K)**2 + ccf_c2*(V_K) + ccf_c3)
    Rphot = 10**(R_c0*(V_K)**3 + R_c1*(V_K)**2 + R_c2*(V_K) + R_c3)
    #print(Rphot)

    spectra = sorted(glob.glob("Spectra/%s/*.fits" % star_names[j]))
    #print(spectrum)
    
    #speed of light, target star RV in meters per second
    c = 299792458e10
    RV = 14.89 * 10 ** 13 #short_stars_rv[j] * (10**13)

    all_S = []
    all_RHK_PRIME = []
    all_err_S = []
    all_err_RHK_PRIME = []

    for i in range(len(spectra)): #range(0,55):
        #print(spectra[i])
        
        if (V-K < 1.45 or V-K > 6.73):
            S = "nan"
            RHK_PRIME = "nan"
            err_S = "nan"
            err_RHK_PRIME = "nan"

            all_S.append(S)
            all_RHK_PRIME.append(RHK_PRIME)
            all_err_S.append(err_S)
            all_err_RHK_PRIME.append(err_RHK_PRIME)
            
        
        elif "ADP" in spectra[i]:
            hdu = pyfits.open(spectra[i])
            #print(spectra[i])
            #print(i)
            
            wave = hdu[1].data[0][0] 
            flux = hdu[1].data[0][1]
            err = np.nan_to_num(hdu[1].data[0][2])
            #print("HARPS Error Array: ", err)

            wave = wave / (1 + RV / c)
            
            try:
                SNR = hdu[0].header["SNR "]
                #print(SNR)
            except KeyError:
                SNR=10
            
            if SNR < 5:
                print("Low signal to noise (%s):" % SNR, spectra[i])
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
            
            #TESTING FOR RANGES (PARTICULARLY FOR UVES)
            elif (np.min(wave)>3891 or np.max(wave)<4011):
                print("Spectrum range not inclusive of all regions: ", spectra[i])
                print(wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)

            else:
                #fnding mean V continuum flux
                V_idx_cont = np.where((wave > (3901 - 10)) & (wave < (3901 + 10)))[0]
                V_sub_cont = flux[V_idx_cont]
                V_err_cont = np.std(V_sub_cont)
                V_mean_cont = np.mean(V_sub_cont)

                #finding mean K line flux
                K_idx_wave = np.where((wave > (3933.6614 - 1.09/.5)) & (wave < (3933.6614 + 1.09/.5)))[0]
                K_sub_flux = flux[K_idx_wave]
                K_err_flux = err[K_idx_wave] 
                K_mean_flux = np.mean(K_sub_flux)

                #finding mean H line flux
                H_idx_wave = np.where((wave > (3968.4673 - 1.09/.5)) & (wave < (3968.4673 + 1.09/.5)))[0]
                H_sub_flux = flux[H_idx_wave]
                H_err_flux = err[H_idx_wave] 
                H_mean_flux = np.mean(H_sub_flux)

                #finding mean R continuum flux                      
                R_idx_cont = np.where(((wave > (4001 - 10)) & (wave < (4001 + 10))))[0]
                R_sub_cont = flux[R_idx_cont]
                R_err_cont = np.std(R_sub_cont)
                R_mean_cont = np.mean(R_sub_cont)

                #S INDEX!!!
                S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
                S = S_instrument_calibrated

                #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
                Rhk = 1.887e-4 * Ccf * S
                #print(Rhk)
                RHK_PRIME = Rhk - Rphot
                #print(RHK_PRIME)

                func_var_S = (R_err_cont**2)*((1/R_mean_cont**2)**2)+(V_err_cont**2)*((1/V_mean_cont**2)**2)
                err_S = np.sqrt(func_var_S)
                func_var_RHK_PRIME = ((ccf_rms**2) * (S * 1.884e-4)**2) + ((err_S**2) * (Ccf * 1.884e-4)**2) + (R_rms**2)
                err_RHK_PRIME = np.sqrt(np.sum(func_var_RHK_PRIME))

                """plt.figure(figsize=(16,4))
                plt.plot(wave,flux)
                #plt.xlim(3880,4020)
                plt.xlim(3920,3940)
                #plt.xlim(3925,3975)
                plt.ylim(-100,1000)
                plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
                plt.axvline(3968.4673 + 1.09/2) # + 3968.4673 * RV / c )
                plt.axvline(3968.4673 - 1.09/2) # + 3968.4673 * RV / c )
                plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
                plt.axvline(3933.6614 + 1.09/2) # + 3933.6614 * RV / c )
                plt.axvline(3933.6614 - 1.09/2) # + 3933.6614 * RV / c )
                plt.show()"""

                #TESTING FOR NOISY SPECTRA
                if H_mean_flux < 0.0:
                    print(spectra[i], " H flux negative: ", H_mean_flux)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                if K_mean_flux < 0.0:
                    print(spectra[i], " K flux negative: ", K_mean_flux)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                if V_mean_cont < 0.0:
                    print(spectra[i], " V flux negative: ", V_mean_cont)
                if R_mean_cont < 0.0:
                    print(spectra[i], " R flux negative: ", R_mean_cont)
                if S < 0.0:
                    print(spectra[i], " S INDEX negative: ", S)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                    
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)

        #######################################################################
        
        #HIRES TARGET SPECTRA
        elif "HI" in spectra[i]:
            try:
                test_file = glob.glob("%s/HI.*_flux.fits" % spectra[i])

                #would be better if I only averaged the SNR for the one or two files including the peaks, but this will do for now
                all_SNR = []
                for f in test_file:
                    hdu = pyfits.open(f)
                    #wave = hdu[1].data["wave"]
                    order_SNR = hdu[0].header["SIG2NOIS "]
                    all_SNR.append(order_SNR)

                SNR = np.mean(np.array(all_SNR))
                #print(SNR)
            except KeyError:
                SNR=10
            
            merged_file = glob.glob("%s/HI*MERGED.txt" % spectra[i])
            wave = np.genfromtxt(merged_file[0], usecols=0)
            flux = np.genfromtxt(merged_file[0], usecols=1)
            
            wave = wave / (1 + RV / c)
            #print("HI ", wave)
            
            if len(wave) == 0:
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
                
            elif SNR < 5:
                print("Low signal to noise (%s):" % SNR, spectra[i])
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)

            #TESTING FOR RANGES
            elif (np.min(wave)>3891 or np.max(wave)<4011):
                print("Spectrum range not inclusive of all regions: ", spectra[i])
                print(wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
                
            else:
                #fnding mean V continuum flux
                V_idx_cont = np.where((wave > (3901 - 10)) & (wave < (3901 + 10)))[0]
                V_sub_cont = flux[V_idx_cont]
                V_mean_cont = np.mean(V_sub_cont)
                V_err_cont = np.sqrt(np.sum((V_sub_cont-V_mean_cont)**2)/len(V_sub_cont)) #np.std(V_sub_cont)

                #finding mean K line flux
                K_idx_wave = np.where((wave > (3933.6614 - 1.09/.5)) & (wave < (3933.6614 + 1.09/.5)))[0]
                K_sub_flux = flux[K_idx_wave] 
                K_mean_flux = np.mean(K_sub_flux)

                #finding mean H line flux
                H_idx_wave = np.where((wave > (3968.4673 - 1.09/.5)) & (wave < (3968.4673 + 1.09/.5)))[0]
                H_sub_flux = flux[H_idx_wave]
                H_mean_flux = np.mean(H_sub_flux)

                #finding mean R continuum flux                      
                R_idx_cont = np.where(((wave > (4001 - 10)) & (wave < (4001 + 10))))[0]
                R_sub_cont = flux[R_idx_cont]
                R_mean_cont = np.mean(R_sub_cont)
                R_err_cont = np.sqrt(np.sum((R_sub_cont-R_mean_cont)**2)/len(R_sub_cont)) #np.std(R_sub_cont)

                #S INDEX!!!
                S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
                S = S_instrument_calibrated

                #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
                Rhk = 1.887e-4 * Ccf * S
                #print(Rhk)
                RHK_PRIME = Rhk - Rphot
                #print(RHK_PRIME)
                
                func_var_S = (R_err_cont**2)*((-1/R_mean_cont**2)**2)+(V_err_cont**2)*((-1/V_mean_cont**2)**2)
                err_S = np.sqrt(func_var_S)
                func_var_RHK_PRIME = ((ccf_rms**2) * (S * 1.884e-4)**2) + ((err_S**2) * (Ccf * 1.884e-4)**2) + (R_rms**2)
                err_RHK_PRIME = np.sqrt(np.sum(func_var_RHK_PRIME))

                #TESTING FOR NOISY SPECTRA
                if H_mean_flux < 0.0:
                    print(spectra[i], " H flux negative: ", H_mean_flux)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                if K_mean_flux < 0.0:
                    print(spectra[i], " K flux negative: ", K_mean_flux)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                if V_mean_cont < 0.0:
                    print(spectra[i], " V flux negative: ", V_mean_cont)
                if R_mean_cont < 0.0:
                    print(spectra[i], " R flux negative: ", R_mean_cont)
                if S < 0.0:
                    print(spectra[i], " S INDEX negative: ", S)
                    S = "nan"
                    RHK_PRIME = "nan"
                    err_S = "nan"
                    err_RHK_PRIME = "nan"
                    
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
                
        """plt.figure(figsize=(16,4))
        plt.subplot(211)
        plt.title(star_names[j], fontsize=20)
        plt.plot(wave,flux)
        plt.xlim(3960,3980)
        plt.ylim(min(flux[(wave > 3960) & (wave < 3980)]),max(flux[(wave > 3960) & (wave < 3980)]))
        plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
        plt.axvline(3968.4673 + 1.09/2) # + 3968.4673 * RV / c )
        plt.axvline(3968.4673 - 1.09/2) # + 3968.4673 * RV / c )
        plt.subplot(212)
        plt.plot(wave,flux)
        plt.xlim(3920,3940)
        plt.ylim(min(flux[(wave > 3920) & (wave < 3940)]),max(flux[(wave > 3920) & (wave < 3940)]))
        plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
        plt.axvline(3933.6614 + 1.09/2) # + 3933.6614 * RV / c )
        plt.axvline(3933.6614 - 1.09/2) # + 3933.6614 * RV / c )
        plt.show()"""
    
    output = np.column_stack((np.nan_to_num(np.array(all_S).astype("float")), 
                          np.nan_to_num(np.array(all_err_S).astype("float")), 
                          np.nan_to_num(np.array(all_RHK_PRIME).astype("float")),
                          np.nan_to_num(np.array(all_err_RHK_PRIME).astype("float"))))
    #print(output)
    np.savetxt("Results/%s_spectra_cahk.txt" % star_names[j], output)
    
    #AVERAGING CALCULATED INDEX VALUES FOR EACH STAR
    #stars_S_avgs.append(np.nanmean(np.array(all_S).astype("float")))
    #stars_S_avgs_err.append(np.nanstd(np.array(all_S).astype("float"), ddof=1))
    #stars_RHK_PRIME_avgs.append(np.nanmean(np.array(all_RHK_PRIME).astype("float")))
    #stars_RHK_PRIME_avgs_err.append(np.nanstd(np.array(all_RHK_PRIME).astype("float"), ddof=1))

    non_nan = np.where(np.logical_not(np.logical_and(np.isnan(np.array(all_S).astype("float")), 
                                                     np.isnan(np.array(all_RHK_PRIME).astype("float")))))[0]
    #non_nan_RHK = np.where(np.logical_not(np.isnan(all_RHK_PRIME)))[0]
    all_S = np.array(all_S).astype("float")
    all_RHK_PRIME = np.array(all_RHK_PRIME).astype("float")
    all_err_S = np.array(all_err_S).astype("float")
    all_err_RHK_PRIME = np.array(all_err_RHK_PRIME).astype("float")
    #print(all_RHK_PRIME)
    #print(all_err_RHK_PRIME)
    
    if len(non_nan) != 0:
        stars_S_avgs.append(np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2))) #np.nanmean takes average while ignoring nan
        stars_S_avgs_err.append(np.sqrt(1/np.sum(1/((all_err_S[non_nan])**2))))
        stars_RHK_PRIME_avgs.append(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2)))
        stars_RHK_PRIME_avgs_err.append(np.sqrt(1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2))))
        print("Average S: ", np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2)),
              "Error: ", np.sqrt(1/np.sum(1/((all_err_S[non_nan])**2))))
        #print("Average log(R'HK): ", np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))),
              #"Error: ", (1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2)))/np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))))
        #SHOULD THIS ERROR INCLUDE NATURAL LOG AS WELL?
        print("Average log(R'HK): ", np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))),
              "Error: ", 0.434*np.sqrt(1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2)))/np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2)))
        log_stars_S_avgs.append(np.log10(np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2)))) #np.nanmean takes average while ignoring nan
        log_stars_S_avgs_err.append(0.434*np.sqrt(1/np.sum(1/((all_err_S[non_nan])**2)))/np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2)))
        log_stars_RHK_PRIME_avgs.append(np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))))
        log_stars_RHK_PRIME_avgs_err.append(0.434*np.sqrt(1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2)))/np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2)))
    else:
        stars_S_avgs.append("nan") #np.nanmean takes average while ignoring nan
        stars_S_avgs_err.append("nan")
        stars_RHK_PRIME_avgs.append("nan")
        stars_RHK_PRIME_avgs_err.append("nan")
        log_stars_S_avgs.append("nan") #np.nanmean takes average while ignoring nan
        log_stars_S_avgs_err.append("nan")
        log_stars_RHK_PRIME_avgs.append("nan")
        log_stars_RHK_PRIME_avgs_err.append("nan")
        print("Average S: nan", "Error: nan")
        print("Average log(R'HK): nan", "Error: nan")
        
print("Star names: ", star_names)
print("S averages for each star: ", stars_S_avgs)
print("R'HK averages for each star: ", stars_RHK_PRIME_avgs)
print("log(R'HK) averages for each star: ", np.log10(np.nan_to_num(np.array(stars_RHK_PRIME_avgs).astype("float"))))
# Out:
# GJ176
# Average S:  0.742459761888 Error:  0.00116179559209
# Average log(R'HK):  -5.23336933017 Error:  0.0101830919147
# GJ667C
# Average S:  0.303262138436 Error:  0.000133712132147
# Average log(R'HK):  -5.51729309251 Error:  0.00926639244182
# GJ581
# Average S:  0.515078404497 Error:  0.00339687314847
# Average log(R'HK):  -5.67142737253 Error:  0.0388616143367
# GJ1214
# Low signal to noise (4.25): Spectra/GJ1214/ADP.2014-09-23T11:01:06.957.fits
# Low signal to noise (2.45): Spectra/GJ1214/ADP.2014-09-23T11:01:26.173.fits
# Low signal to noise (3.9): Spectra/GJ1214/ADP.2014-09-23T11:01:26.863.fits
# Low signal to noise (3.9): Spectra/GJ1214/ADP.2014-09-23T11:01:37.190.fits
# Low signal to noise (4.55): Spectra/GJ1214/ADP.2014-09-23T11:01:56.790.fits
# Low signal to noise (4.45): Spectra/GJ1214/ADP.2014-09-23T11:02:04.590.fits
# Low signal to noise (4.25): Spectra/GJ1214/ADP.2014-09-23T11:02:05.660.fits
# Low signal to noise (4.6): Spectra/GJ1214/ADP.2014-09-23T11:02:13.567.fits
# Low signal to noise (3.95): Spectra/GJ1214/ADP.2014-09-23T11:02:55.500.fits
# Low signal to noise (2.05): Spectra/GJ1214/ADP.2014-09-23T11:03:17.930.fits
# Low signal to noise (4.65): Spectra/GJ1214/ADP.2014-09-23T11:03:24.823.fits
# Low signal to noise (3.15): Spectra/GJ1214/ADP.2014-09-23T11:03:36.243.fits
# Low signal to noise (3.5): Spectra/GJ1214/ADP.2014-09-23T11:03:58.940.fits
# Low signal to noise (4.85): Spectra/GJ1214/ADP.2014-09-23T11:03:59.030.fits
# Low signal to noise (3.95): Spectra/GJ1214/ADP.2014-09-23T11:03:59.207.fits
# Low signal to noise (4.15): Spectra/GJ1214/ADP.2014-09-23T11:04:10.397.fits
# Low signal to noise (4.85): Spectra/GJ1214/ADP.2014-09-23T11:04:13.120.fits
# Low signal to noise (3.8): Spectra/GJ1214/ADP.2014-09-23T11:04:14.727.fits
# Low signal to noise (4.0): Spectra/GJ1214/ADP.2014-09-23T11:04:17.520.fits
# Low signal to noise (4.9): Spectra/GJ1214/ADP.2014-09-23T11:04:18.737.fits
# Low signal to noise (3.55): Spectra/GJ1214/ADP.2014-09-23T11:04:21.670.fits
# Low signal to noise (4.7): Spectra/GJ1214/ADP.2014-09-23T11:04:45.917.fits
# Low signal to noise (4.4): Spectra/GJ1214/ADP.2014-09-23T11:04:46.417.fits
# Low signal to noise (4.65): Spectra/GJ1214/ADP.2014-09-23T11:05:31.390.fits
# Low signal to noise (4.9): Spectra/GJ1214/ADP.2014-09-23T11:06:15.113.fits
# Low signal to noise (4.9): Spectra/GJ1214/ADP.2014-09-24T09:41:58.570.fits
# Low signal to noise (4.4): Spectra/GJ1214/ADP.2014-09-24T09:42:02.453.fits
# Low signal to noise (3.65): Spectra/GJ1214/ADP.2014-09-24T09:42:27.490.fits
# Low signal to noise (3.5): Spectra/GJ1214/ADP.2014-09-24T09:42:57.487.fits
# Low signal to noise (4.55): Spectra/GJ1214/ADP.2014-09-24T09:43:40.127.fits
# Low signal to noise (4.4): Spectra/GJ1214/ADP.2014-09-24T09:43:43.080.fits
# Low signal to noise (3.4): Spectra/GJ1214/ADP.2014-09-24T09:43:43.180.fits
# Low signal to noise (4.95): Spectra/GJ1214/ADP.2014-09-24T09:44:16.237.fits
# Low signal to noise (2.9): Spectra/GJ1214/ADP.2014-09-24T09:44:31.900.fits
# Low signal to noise (4.4): Spectra/GJ1214/ADP.2014-09-25T15:32:41.520.fits
# Low signal to noise (3.05): Spectra/GJ1214/ADP.2014-09-25T15:33:33.690.fits
# Low signal to noise (3.55): Spectra/GJ1214/ADP.2014-09-25T15:34:03.067.fits
# Low signal to noise (2.8): Spectra/GJ1214/ADP.2014-09-25T15:34:10.750.fits
# Low signal to noise (3.9): Spectra/GJ1214/ADP.2014-09-25T15:34:26.657.fits
# Low signal to noise (4.45): Spectra/GJ1214/ADP.2014-09-25T15:34:30.900.fits
# Low signal to noise (3.15): Spectra/GJ1214/ADP.2014-09-25T15:35:18.113.fits
# Low signal to noise (4.95): Spectra/GJ1214/ADP.2014-09-25T15:35:24.213.fits
# Low signal to noise (4.25): Spectra/GJ1214/ADP.2014-09-25T15:35:33.550.fits
# Low signal to noise (4.65): Spectra/GJ1214/ADP.2014-09-25T15:36:41.050.fits
# Low signal to noise (1.9): Spectra/GJ1214/ADP.2014-09-25T15:37:32.197.fits
# Low signal to noise (2.45): Spectra/GJ1214/ADP.2014-09-25T15:37:32.343.fits
# Low signal to noise (3.55): Spectra/GJ1214/ADP.2014-09-26T16:51:10.497.fits
# Low signal to noise (2.1): Spectra/GJ1214/ADP.2014-09-26T16:51:11.567.fits
# Low signal to noise (2.65): Spectra/GJ1214/ADP.2014-09-26T16:51:22.130.fits
# Low signal to noise (2.9): Spectra/GJ1214/ADP.2014-09-26T16:51:25.453.fits
# Low signal to noise (4.1): Spectra/GJ1214/ADP.2014-09-26T16:51:27.907.fits
# Low signal to noise (2.7): Spectra/GJ1214/ADP.2014-09-26T16:51:48.450.fits
# Low signal to noise (3.2): Spectra/GJ1214/ADP.2014-09-26T16:52:03.477.fits
# Low signal to noise (3.05): Spectra/GJ1214/ADP.2014-09-26T16:52:03.663.fits
# Low signal to noise (2.05): Spectra/GJ1214/ADP.2014-09-26T16:52:07.030.fits
# Low signal to noise (1.95): Spectra/GJ1214/ADP.2014-09-26T16:52:16.397.fits
# Low signal to noise (2.85): Spectra/GJ1214/ADP.2014-09-26T16:52:18.310.fits
# Low signal to noise (3.5): Spectra/GJ1214/ADP.2014-09-26T16:52:18.543.fits
# Low signal to noise (3.9): Spectra/GJ1214/ADP.2014-09-26T16:52:41.990.fits
# Low signal to noise (1.65): Spectra/GJ1214/ADP.2014-09-26T16:53:00.650.fits
# Low signal to noise (4.6): Spectra/GJ1214/ADP.2014-09-26T16:53:06.640.fits
# Low signal to noise (4.45): Spectra/GJ1214/ADP.2014-09-26T16:53:20.240.fits
# Low signal to noise (1.25): Spectra/GJ1214/ADP.2014-09-26T16:53:35.800.fits
# Low signal to noise (2.6): Spectra/GJ1214/ADP.2014-09-26T16:53:37.937.fits
# Low signal to noise (3.05): Spectra/GJ1214/ADP.2014-09-26T16:53:52.387.fits
# Low signal to noise (1.65): Spectra/GJ1214/ADP.2014-09-26T16:54:04.660.fits
# Low signal to noise (1.45): Spectra/GJ1214/ADP.2014-09-26T16:54:09.650.fits
# Low signal to noise (1.7): Spectra/GJ1214/ADP.2014-09-26T16:54:12.410.fits
# Low signal to noise (3.65): Spectra/GJ1214/ADP.2014-09-26T16:54:14.990.fits
# Low signal to noise (4.6): Spectra/GJ1214/ADP.2014-09-26T16:54:31.133.fits
# Low signal to noise (0.8): Spectra/GJ1214/ADP.2014-09-26T16:54:51.993.fits
# Low signal to noise (1.65): Spectra/GJ1214/ADP.2014-09-26T16:54:55.927.fits
# Low signal to noise (3.6): Spectra/GJ1214/ADP.2017-04-30T01:01:30.814.fits
# Low signal to noise (2.9): Spectra/GJ1214/ADP.2017-05-01T01:01:54.158.fits
# Low signal to noise (3.7): Spectra/GJ1214/ADP.2017-05-02T01:01:54.400.fits
# Low signal to noise (3.65): Spectra/GJ1214/ADP.2017-05-03T01:01:26.720.fits
# Low signal to noise (4.5): Spectra/GJ1214/ADP.2017-05-04T01:01:47.561.fits
# Low signal to noise (3.5): Spectra/GJ1214/ADP.2017-05-05T01:01:30.651.fits
# Average S:  0.597007568774 Error:  0.112896505267
# Average log(R'HK):  -6.08037964502 Error:  0.275874894648
# GJ832
# Spectrum range not inclusive of all regions:  Spectra/GJ832/HI.20091203.16313_1.fits
# [ 3926.8322633   3926.8422628   3926.8522623  ...,  4927.30257227
#   4927.31257177  4927.32257127]
# Average S:  0.488469801354 Error:  0.000315218800544
# Average log(R'HK):  -5.43942749372 Error:  0.0132307700623
# GJ876
# Spectra/GJ876/ADP.2014-09-29T13:27:06.833.fits  K flux negative:  -0.253551
# Average S:  0.686859503391 Error:  0.00102961937889
# Average log(R'HK):  -5.65366922422 Error:  0.0163388021562
# GJ436
# Average S:  0.510439279001 Error:  0.00234313875323
# Average log(R'HK):  -5.56743212137 Error:  0.0137739951205
# GJ628
# Spectra/GJ628/ADP.2014-10-07T08:34:03.220.fits  K flux negative:  -0.160783
# Average S:  0.629482290427 Error:  0.000968158211307
# Average log(R'HK):  -5.67735195793 Error:  0.0154317625532
# GJ887
# Low signal to noise (0.7): Spectra/GJ887/ADP.2014-09-16T11:08:09.950.fits
# Spectra/GJ887/ADP.2014-10-07T08:34:06.273.fits  K flux negative:  -0.715693
# Spectra/GJ887/ADP.2014-10-07T08:34:13.027.fits  K flux negative:  -0.483849
# Spectra/GJ887/ADP.2014-10-07T08:34:13.027.fits  V flux negative:  -0.0592859
# Spectra/GJ887/ADP.2014-10-07T08:34:53.983.fits  K flux negative:  -0.508748
# Spectra/GJ887/ADP.2014-10-07T08:35:01.637.fits  K flux negative:  -0.906068
# Spectra/GJ887/ADP.2014-10-07T08:35:05.887.fits  K flux negative:  -0.45453
# Spectra/GJ887/ADP.2014-10-07T08:35:22.063.fits  K flux negative:  -0.15693
# Spectra/GJ887/ADP.2014-10-07T08:35:24.323.fits  K flux negative:  -0.0057827
# Spectra/GJ887/ADP.2014-10-07T08:35:35.827.fits  K flux negative:  -0.387794
# Spectra/GJ887/ADP.2014-10-07T08:35:47.743.fits  K flux negative:  -0.0663304
# Spectra/GJ887/ADP.2014-10-07T08:35:48.370.fits  K flux negative:  -0.408921
# Average S:  0.580226888943 Error:  0.000104229964532
# Average log(R'HK):  -5.16111685549 Error:  0.00574093357175
# GJ1061
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2013-09-28T09:05:29.783.fits
# [  6506.49102817   6506.51086195   6506.53069573 ...,  10251.88950424
#   10251.91410286  10251.93870147]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2013-09-28T09:06:58.660.fits
# [  6506.49301345   6506.51284276   6506.53267207 ...,  10251.88557001
#   10251.91009505  10251.9346201 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2013-09-28T09:06:58.713.fits
# [  6506.48703436   6506.50687097   6506.52670757 ...,  10251.96677813
#   10251.99125354  10252.01572895]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2013-09-28T09:09:33.863.fits
# [  6506.482892     6506.50273144   6506.52257088 ...,  10251.89800045
#   10251.9225213   10251.94704215]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2013-09-28T09:13:02.137.fits
# [  6506.46062458   6506.48045204   6506.5002795  ...,  10251.98345085
#   10252.00796053  10252.03247022]
# Low signal to noise (3.7): Spectra/GJ1061/ADP.2014-09-29T13:27:14.183.fits
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2015-10-14T11:24:24.153.fits
# [  6506.43252067   6506.45226777   6506.47201487 ...,  10251.84953011
#   10251.87435149  10251.89917287]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2015-10-14T11:24:24.527.fits
# [  6506.43252067   6506.45226777   6506.47201487 ...,  10251.84953011
#   10251.87435149  10251.89917287]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2015-10-14T11:36:04.307.fits
# [  6506.43055053   6506.45029463   6506.47003872 ...,  10251.82419055
#   10251.84903111  10251.87387167]
# Spectrum range not inclusive of all regions:  Spectra/GJ1061/ADP.2015-10-14T11:36:04.760.fits
# [  6506.43055053   6506.45029463   6506.47003872 ...,  10251.82419055
#   10251.84903111  10251.87387167]
# Average S:  1.08628832734 Error:  0.471534643293
# Average log(R'HK):  -5.95555777226 Error:  0.524621752205
# HD173739
# Spectrum range not inclusive of all regions:  Spectra/HD173739/HI.20080812.19286.fits
# [ 5444.80356916  5444.81356867  5444.82356817 ...,  6794.98650872
#   6794.99650822  6795.00650773]
# Spectrum range not inclusive of all regions:  Spectra/HD173739/HI.20080812.19423.fits
# [ 5444.80366916  5444.81366866  5444.82366817 ...,  6794.98660872
#   6794.99660822  6795.00660772]
# Spectrum range not inclusive of all regions:  Spectra/HD173739/HI.20080812.19504.fits
# [ 5444.80386915  5444.81386865  5444.82386816 ...,  6794.98680871
#   6794.99680821  6795.00680771]
# Spectrum range not inclusive of all regions:  Spectra/HD173739/HI.20091202.18717.fits
# [ 3927.0677516   3927.0777511   3927.08775061 ...,  4861.00136529
#   4861.0113648   4861.0213643 ]
# Spectrum range not inclusive of all regions:  Spectra/HD173739/HI.20091202.19326.fits
# [ 4016.28432042  4016.29431992  4016.30431943 ...,  4927.59905754
#   4927.60905704  4927.61905655]
# Average S:  0.188489207377 Error:  1.27753742135e-05
# Average log(R'HK):  -7.16480407795 Error:  0.678826663026
# GSC8056-0482
# Spectrum range not inclusive of all regions:  Spectra/GSC8056-0482/ADP.2013-09-28T06:30:01.463.fits
# [ 4726.26669929  4726.29510422  4726.32350914 ...,  6834.78551659
#   6834.8195183   6834.85352001]
# Average S:  4.21814 Error:  0.003271224703
# Average log(R'HK):  -4.53521854451 Error:  0.10418256496
# 2MASSJ02543316-5108313
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ02001277-0840516
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# G75-55
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ22025453-6440441
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ00240899-6211042
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ00240899-6211042/ADP.2015-09-15T10:37:12.997.fits
# [ 4726.26936578  4726.29788419  4726.32640259 ...,  6834.68852419
#   6834.7226507   6834.75677722]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ00240899-6211042/ADP.2015-10-14T10:52:58.623.fits
# [ 4726.25906427  4726.28757383  4726.3160834  ...,  6834.68142102
#   6834.71555381  6834.7496866 ]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ00240899-6211042/ADP.2015-10-14T11:29:31.410.fits
# [ 4726.23303112  4726.26142663  4726.28982213 ...,  6834.67837277
#   6834.71245601  6834.74653925]
# Average S:  2.46309725085 Error:  0.00117482891508
# Average log(R'HK):  -4.36376232515 Error:  0.0241850755277
# 2MASSJ01521830-5950168
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ01521830-5950168/ADP.2015-09-15T10:37:13.003.fits
# [ 4726.26936578  4726.29788419  4726.32640259 ...,  6834.68852419
#   6834.7226507   6834.75677722]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ01521830-5950168/ADP.2015-10-14T10:52:58.557.fits
# [ 4726.25906427  4726.28757383  4726.3160834  ...,  6834.68142102
#   6834.71555381  6834.7496866 ]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ01521830-5950168/ADP.2015-10-14T10:56:24.207.fits
# [ 4726.26513038  4726.29358043  4726.32203049 ...,  6834.70371713
#   6834.73782891  6834.77194068]
# Average S:  2.98581695697 Error:  0.00124192223866
# Average log(R'HK):  -4.50278557982 Error:  0.0394919771784
# 2MASSJ03315564-4359135
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ03315564-4359135/ADP.2013-09-27T15:14:45.743.fits
# [ 4726.63230766  4726.66077449  4726.68924132 ...,  6834.69799168
#   6834.73185465  6834.76571762]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ03315564-4359135/ADP.2013-09-27T15:14:45.757.fits
# [ 4726.63230766  4726.66077449  4726.68924132 ...,  6834.69799168
#   6834.73185465  6834.76571762]
# Average S:  1.71946 Error:  0.000674305626809
# Average log(R'HK):  -4.3920586369 Error:  0.0306834912663
# 2MASSJ23261069-7323498
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ23261069-7323498/ADP.2015-09-15T10:33:13.947.fits
# [ 4726.27257909  4726.30112749  4726.32967588 ...,  6834.73159712
#   6834.76576428  6834.79993145]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ23261069-7323498/ADP.2015-09-15T10:37:12.963.fits
# [ 4726.26936578  4726.29788419  4726.32640259 ...,  6834.68852419
#   6834.7226507   6834.75677722]
# Spectrum range not inclusive of all regions:  Spectra/2MASSJ23261069-7323498/ADP.2015-10-14T10:52:59.237.fits
# [ 4726.25906427  4726.28757383  4726.3160834  ...,  6834.68142102
#   6834.71555381  6834.7496866 ]
# Average S:  3.17699629113 Error:  0.00114140643978
# Average log(R'HK):  -4.2905261803 Error:  0.0258054230443
# 2MASSJ23285763-6802338
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ00393579-3816584
# V-K out of valid spectral range:  -7.86100006104
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ173
# Average S:  0.496395270117 Error:  0.00315114012966
# Average log(R'HK):  -5.45264003306 Error:  0.0280771431581
# GJ3290
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# LP415-1619
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# LP5-282
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ02001277-0840516
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04223953+1816097
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04184702+1321585
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# TYC1265-1118-1
# Average S:  0.938689574915 Error:  0.000891168786
# Average log(R'HK):  -4.87813812365 Error:  0.0519587711411
# 2MASSJ02125819-5851182
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ3997
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ22463471-7353504
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ4334
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ49
# Average S:  1.04850290697 Error:  4.99868405343e-05
# Average log(R'HK):  -5.03093645222 Error:  0.0160677732202
# GJ871.1A
# Spectrum range not inclusive of all regions:  Spectra/GJ871.1A/ADP.2013-09-28T06:25:44.387.fits
# [ 4726.28401559  4726.31240014  4726.3407847  ...,  6834.77265425
#   6834.8065941   6834.84053394]
# Spectrum range not inclusive of all regions:  Spectra/GJ871.1A/ADP.2013-09-28T06:36:17.623.fits
# [ 4726.27848642  4726.30692303  4726.33535964 ...,  6834.78340794
#   6834.81741607  6834.8514242 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ871.1A/HI.20060616.52044_1.fits
# [ 4778.29837294  4778.30837244  4778.31837195 ...,  6099.09277216
#   6099.10277166  6099.11277116]
# Average S:  4.7145911043 Error:  0.00113820221223
# Average log(R'HK):  -4.5806056869 Error:  0.0928459389569
# LP247-13
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# G80-21
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2014-08-11T13:07:28.653.fits
# [ 4726.03719336  4726.06569747  4726.09420157 ...,  6834.91027086
#   6834.94431112  6834.97835139]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2014-08-11T13:07:28.700.fits
# [ 4726.03719336  4726.06569747  4726.09420157 ...,  6834.91027086
#   6834.94431112  6834.97835139]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2014-08-11T13:10:10.680.fits
# [ 4726.04107037  4726.06954856  4726.09802675 ...,  6834.88153011
#   6834.91558058  6834.94963104]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:07.960.fits
# [ 298.90515407  298.92515308  298.94515208 ...,  555.91238911  555.93238812
#   555.95238713]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:07.980.fits
# [ 298.90515407  298.92515308  298.94515208 ...,  555.91238911  555.93238812
#   555.95238713]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.000.fits
# 1528.9123437
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.060.fits
# [  993.97063177   994.03062879   994.09062581 ...,  2478.71688785
#   2478.77688487  2478.83688189]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.113.fits
# [  993.97063177   994.03062879   994.09062581 ...,  2478.71688785
#   2478.77688487  2478.83688189]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.180.fits
# 217.740039847
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.240.fits
# [  533.63349565   533.65349466   533.67349367 ...,  1019.90934346
#   1019.92934246  1019.94934147]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.260.fits
# [  993.97063177   994.03062879   994.09062581 ...,  2478.71688785
#   2478.77688487  2478.83688189]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.293.fits
# 1002.75823974
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.313.fits
# 3277.91580676
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.320.fits
# 255.893342004
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.327.fits
# [ 298.90515407  298.92515308  298.94515208 ...,  555.91238911  555.93238812
#   555.95238713]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.353.fits
# 4069.36990527
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.380.fits
# 235.924378372
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.480.fits
# [  533.63349565   533.65349466   533.67349367 ...,  1019.90934346
#   1019.92934246  1019.94934147]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.500.fits
# 1353.68325396
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.507.fits
# [  533.63349565   533.65349466   533.67349367 ...,  1019.90934346
#   1019.92934246  1019.94934147]
# Spectrum range not inclusive of all regions:  Spectra/G80-21/ADP.2015-02-05T13:30:08.567.fits
# 2944.44360003
# Spectrum range not inclusive of all regions:  Spectra/G80-21/HI.20051221.40554_1.fits
# [ 4778.51896198  4778.52896149  4778.53896099 ...,  6204.35814387
#   6204.36814337  6204.37814288]
# Average S:  3.63076857974 Error:  0.00147407415426
# Average log(R'HK):  -4.49370325008 Error:  0.040236725483
# CD-571054
# Spectrum range not inclusive of all regions:  Spectra/CD-571054/ADP.2013-09-27T15:27:59.340.fits
# [ 4726.63136638  4726.65981658  4726.68826679 ...,  6834.69220618
#   6834.72603577  6834.75986535]
# Spectrum range not inclusive of all regions:  Spectra/CD-571054/ADP.2013-09-27T15:27:59.347.fits
# [ 4726.63136638  4726.65981658  4726.68826679 ...,  6834.69220618
#   6834.72603577  6834.75986535]
# Average S:  2.12200778946 Error:  0.000470915742135
# Average log(R'HK):  -4.42276621138 Error:  0.0104810375119
# CD-352722
# Spectrum range not inclusive of all regions:  Spectra/CD-352722/ADP.2013-09-27T15:43:38.880.fits
# [ 4726.6518847   4726.68031244  4726.70874018 ...,  6834.70245474
#   6834.7362832   6834.77011166]
# Spectrum range not inclusive of all regions:  Spectra/CD-352722/ADP.2013-09-27T15:43:39.277.fits
# [ 4726.6518847   4726.68031244  4726.70874018 ...,  6834.70245474
#   6834.7362832   6834.77011166]
# Average S:  3.07083 Error:  0.000457622546318
# Average log(R'HK):  -4.34600108803 Error:  0.0490978958884
# GJ410
# Average S:  1.41234178459 Error:  0.00192545172651
# Average log(R'HK):  -4.66759884604 Error:  0.0136021872898
# LP55-41
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# G249-11
# V-K out of valid spectral range:  -9.72999954224
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# G111-72
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ213
# Low signal to noise (0.85): Spectra/GJ213/ADP.2014-09-24T09:41:24.383.fits
# Low signal to noise (4.9): Spectra/GJ213/ADP.2014-10-06T10:04:28.040.fits
# Spectra/GJ213/ADP.2014-10-07T13:37:11.967.fits  K flux negative:  -0.983435
# Average S:  0.842830080245 Error:  0.0140474277953
# Average log(R'HK):  -5.80674067203 Error:  0.0459742460052
# GJ4304
# Average S:  0.638864619357 Error:  0.0602895615936
# Average log(R'HK):  -5.15335849443 Error:  0.072950010153
# GJ821
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-18T09:51:27.116.fits
# [ 4959.27016105  4959.28502078  4959.2998805  ...,  7070.27782982
#   7070.29552684  7070.31322386]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-18T09:51:27.117.fits
# [ 4959.27016105  4959.28502078  4959.2998805  ...,  7070.27782982
#   7070.29552684  7070.31322386]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-18T09:51:27.119.fits
# [ 4959.27016105  4959.28502078  4959.2998805  ...,  7070.27782982
#   7070.29552684  7070.31322386]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:01:51.129.fits
# [ 4959.24410447  4959.25899562  4959.27388677 ...,  7070.25144524
#   7070.26912316  7070.28680109]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:01:51.133.fits
# [ 4959.24410447  4959.25899562  4959.27388677 ...,  7070.25144524
#   7070.26912316  7070.28680109]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:01:51.146.fits
# [ 4959.24410447  4959.25899562  4959.27388677 ...,  7070.25144524
#   7070.26912316  7070.28680109]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:59:27.032.fits
# [ 4959.24152795  4959.25645072  4959.2713735  ...,  7070.25073132
#   7070.26840664  7070.28608196]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:59:27.039.fits
# [ 4959.24152795  4959.25645072  4959.2713735  ...,  7070.25073132
#   7070.26840664  7070.28608196]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T22:59:27.041.fits
# [ 4959.24152795  4959.25645072  4959.2713735  ...,  7070.25073132
#   7070.26840664  7070.28608196]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T23:21:54.728.fits
# [ 4959.27156711  4959.28642368  4959.30128025 ...,  7070.28177599
#   7070.29943342  7070.31709085]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T23:21:54.729.fits
# [ 4959.27156711  4959.28642368  4959.30128025 ...,  7070.28177599
#   7070.29943342  7070.31709085]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-25T23:21:54.747.fits
# [ 4959.27156711  4959.28642368  4959.30128025 ...,  7070.28177599
#   7070.29943342  7070.31709085]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:29:22.018.fits
# [ 4959.28268762  4959.29762743  4959.31256723 ...,  7070.28294884
#   7070.30066841  7070.31838797]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:29:22.036.fits
# [ 4959.28268762  4959.29762743  4959.31256723 ...,  7070.28294884
#   7070.30066841  7070.31838797]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:29:22.052.fits
# [ 4959.28268762  4959.29762743  4959.31256723 ...,  7070.28294884
#   7070.30066841  7070.31838797]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:49:20.265.fits
# [ 4959.273433    4959.28830972  4959.30318644 ...,  7070.27949569
#   7070.29717041  7070.31484514]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:49:20.268.fits
# [ 4959.273433    4959.28830972  4959.30318644 ...,  7070.27949569
#   7070.29717041  7070.31484514]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T05:49:20.277.fits
# [ 4959.273433    4959.28830972  4959.30318644 ...,  7070.27949569
#   7070.29717041  7070.31484514]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:08:29.157.fits
# [ 4959.26635125  4959.28122947  4959.29610768 ...,  7070.29439588
#   7070.31211982  7070.32984377]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:08:29.158.fits
# [ 4959.26635125  4959.28122947  4959.29610768 ...,  7070.29439588
#   7070.31211982  7070.32984377]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:08:29.171.fits
# [ 4959.26635125  4959.28122947  4959.29610768 ...,  7070.29439588
#   7070.31211982  7070.32984377]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:35:12.830.fits
# [ 4959.26606473  4959.28094674  4959.29582875 ...,  7070.28888958
#   7070.30657047  7070.32425137]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:35:12.838.fits
# [ 4959.26606473  4959.28094674  4959.29582875 ...,  7070.28888958
#   7070.30657047  7070.32425137]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:35:12.863.fits
# [ 4959.26606473  4959.28094674  4959.29582875 ...,  7070.28888958
#   7070.30657047  7070.32425137]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:55:15.045.fits
# [ 4959.30745932  4959.32233244  4959.33720555 ...,  7070.29151373
#   7070.30921154  7070.32690934]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:55:15.047.fits
# [ 4959.30745932  4959.32233244  4959.33720555 ...,  7070.29151373
#   7070.30921154  7070.32690934]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T06:55:15.064.fits
# [ 4959.30745932  4959.32233244  4959.33720555 ...,  7070.29151373
#   7070.30921154  7070.32690934]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:16:53.481.fits
# [ 4959.27952529  4959.29439083  4959.30925638 ...,  7070.28967791
#   7070.30735854  7070.32503917]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:16:53.482.fits
# [ 4959.27952529  4959.29439083  4959.30925638 ...,  7070.28967791
#   7070.30735854  7070.32503917]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:16:53.483.fits
# [ 4959.27952529  4959.29439083  4959.30925638 ...,  7070.28967791
#   7070.30735854  7070.32503917]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:29:09.361.fits
# [ 4959.28628263  4959.30118344  4959.31608424 ...,  7070.31023871
#   7070.32792447  7070.34561024]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:29:09.382.fits
# [ 4959.28628263  4959.30118344  4959.31608424 ...,  7070.31023871
#   7070.32792447  7070.34561024]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:29:09.432.fits
# [ 4959.28628263  4959.30118344  4959.31608424 ...,  7070.31023871
#   7070.32792447  7070.34561024]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:38:35.697.fits
# [ 4959.2955846   4959.31047734  4959.32537007 ...,  7070.30260107
#   7070.32028531  7070.33796956]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:38:35.698.fits
# [ 4959.2955846   4959.31047734  4959.32537007 ...,  7070.30260107
#   7070.32028531  7070.33796956]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T07:38:35.700.fits
# [ 4959.2955846   4959.31047734  4959.32537007 ...,  7070.30260107
#   7070.32028531  7070.33796956]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:04:40.060.fits
# [ 4959.2968724   4959.31173808  4959.32660377 ...,  7070.28575216
#   7070.30343221  7070.32111226]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:04:40.065.fits
# [ 4959.2968724   4959.31173808  4959.32660377 ...,  7070.28575216
#   7070.30343221  7070.32111226]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:04:40.075.fits
# [ 4959.2968724   4959.31173808  4959.32660377 ...,  7070.28575216
#   7070.30343221  7070.32111226]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:07:10.848.fits
# [ 4959.28377805  4959.29864387  4959.3135097  ...,  7070.28283311
#   7070.3005089   7070.3181847 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:07:10.849.fits
# [ 4959.28377805  4959.29864387  4959.3135097  ...,  7070.28283311
#   7070.3005089   7070.3181847 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:07:10.850.fits
# [ 4959.28377805  4959.29864387  4959.3135097  ...,  7070.28283311
#   7070.3005089   7070.3181847 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:09:27.375.fits
# [ 4959.28377805  4959.29864387  4959.3135097  ...,  7070.28283311
#   7070.3005089   7070.3181847 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:09:27.376.fits
# [ 4959.29438422  4959.30926783  4959.32415145 ...,  7070.28494154
#   7070.30263083  7070.32032012]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:09:27.377.fits
# [ 4959.28377805  4959.29864387  4959.3135097  ...,  7070.28283311
#   7070.3005089   7070.3181847 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:10:33.634.fits
# [ 4959.29782286  4959.31271184  4959.32760083 ...,  7070.28177155
#   7070.29946194  7070.31715232]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:10:33.635.fits
# [ 4959.29782286  4959.31271184  4959.32760083 ...,  7070.28177155
#   7070.29946194  7070.31715232]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:10:33.636.fits
# [ 4959.29782286  4959.31271184  4959.32760083 ...,  7070.28177155
#   7070.29946194  7070.31715232]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:32:34.875.fits
# [ 4959.26453158  4959.27938768  4959.29424378 ...,  7070.27920032
#   7070.29689867  7070.31459702]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:32:34.880.fits
# [ 4959.26453158  4959.27938768  4959.29424378 ...,  7070.27920032
#   7070.29689867  7070.31459702]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:32:34.881.fits
# [ 4959.26453158  4959.27938768  4959.29424378 ...,  7070.27920032
#   7070.29689867  7070.31459702]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:57:31.947.fits
# [ 4959.30586941  4959.32072876  4959.3355881  ...,  7070.30204157
#   7070.31971839  7070.3373952 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:57:31.950.fits
# [ 4959.29101007  4959.30586941  4959.32072876 ...,  7070.30204157
#   7070.31971839  7070.3373952 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:57:31.951.fits
# [ 4959.30586941  4959.32072876  4959.3355881  ...,  7070.30204157
#   7070.31971839  7070.3373952 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T08:57:31.954.fits
# [ 4959.29101007  4959.30586941  4959.32072876 ...,  7070.30204157
#   7070.31971839  7070.3373952 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:04:50.575.fits
# [ 4959.3069435   4959.32180284  4959.33666219 ...,  7070.31304832
#   7070.33075633  7070.34846435]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:04:50.576.fits
# [ 4959.3069435   4959.32180284  4959.33666219 ...,  7070.31304832
#   7070.33075633  7070.34846435]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:04:50.581.fits
# [ 4959.3069435   4959.32180284  4959.33666219 ...,  7070.31304832
#   7070.33075633  7070.34846435]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:28:39.146.fits
# [ 4959.29584061  4959.31072298  4959.32560535 ...,  7070.29467132
#   7070.31236183  7070.33005234]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:28:39.148.fits
# [ 4959.29584061  4959.31072298  4959.32560535 ...,  7070.29467132
#   7070.31236183  7070.33005234]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:28:39.151.fits
# [ 4959.28095824  4959.29584061  4959.31072298 ...,  7070.29467132
#   7070.31236183  7070.33005234]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:43:30.334.fits
# [ 4959.29561438  4959.31048576  4959.32535715 ...,  7070.28628547
#   7070.30397666  7070.32166786]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:43:30.340.fits
# [ 4959.29561438  4959.31048576  4959.32535715 ...,  7070.28628547
#   7070.30397666  7070.32166786]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:43:30.349.fits
# [ 4959.29561438  4959.31048576  4959.32535715 ...,  7070.28628547
#   7070.30397666  7070.32166786]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:53:19.846.fits
# [ 4959.29903362  4959.31389797  4959.32876233 ...,  7070.30521387
#   7070.32289693  7070.34057999]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:53:19.862.fits
# [ 4959.29903362  4959.31389797  4959.32876233 ...,  7070.30521387
#   7070.32289693  7070.34057999]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T09:53:19.863.fits
# [ 4959.29903362  4959.31389797  4959.32876233 ...,  7070.30521387
#   7070.32289693  7070.34057999]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T14:36:57.720.fits
# [ 4959.27180061  4959.28671163  4959.30162265 ...,  7070.27186279
#   7070.28956471  7070.30726664]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T14:36:57.731.fits
# [ 4959.27180061  4959.28671163  4959.30162265 ...,  7070.27186279
#   7070.28956471  7070.30726664]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T14:36:57.733.fits
# [ 4959.27180061  4959.28671163  4959.30162265 ...,  7070.27186279
#   7070.28956471  7070.30726664]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:09:18.824.fits
# [ 4959.27399744  4959.28888202  4959.3037666  ...,  7070.26366529
#   7070.28139173  7070.29911818]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:09:18.825.fits
# [ 4959.27399744  4959.28888202  4959.3037666  ...,  7070.26366529
#   7070.28139173  7070.29911818]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:09:18.831.fits
# [ 4959.27399744  4959.28888202  4959.3037666  ...,  7070.26366529
#   7070.28139173  7070.29911818]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:27:50.488.fits
# [ 4959.27061897  4959.28551632  4959.30041368 ...,  7070.27418554
#   7070.29189478  7070.30960403]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:27:50.493.fits
# [ 4959.27061897  4959.28551632  4959.30041368 ...,  7070.27418554
#   7070.29189478  7070.30960403]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T15:27:50.499.fits
# [ 4959.27061897  4959.28551632  4959.30041368 ...,  7070.27418554
#   7070.29189478  7070.30960403]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T16:50:14.517.fits
# [ 4959.28569243  4959.30057959  4959.31546675 ...,  7070.27079509
#   7070.28847377  7070.30615246]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T16:50:14.519.fits
# [ 4959.28569243  4959.30057959  4959.31546675 ...,  7070.27079509
#   7070.28847377  7070.30615246]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T16:50:14.520.fits
# [ 4959.28569243  4959.30057959  4959.31546675 ...,  7070.27079509
#   7070.28847377  7070.30615246]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:26:43.921.fits
# [ 4959.25982643  4959.2747243   4959.28962216 ...,  7070.29086782
#   7070.30857502  7070.32628222]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:26:43.922.fits
# [ 4959.25982643  4959.2747243   4959.28962216 ...,  7070.29086782
#   7070.30857502  7070.32628222]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:26:43.923.fits
# [ 4959.25982643  4959.2747243   4959.28962216 ...,  7070.29086782
#   7070.30857502  7070.32628222]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:56:05.388.fits
# [ 4959.27036444  4959.28525415  4959.30014385 ...,  7070.27499096
#   7070.2927318   7070.31047264]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:56:05.391.fits
# [ 4959.27036444  4959.28525415  4959.30014385 ...,  7070.27499096
#   7070.2927318   7070.31047264]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T18:56:05.392.fits
# [ 4959.27036444  4959.28525415  4959.30014385 ...,  7070.27499096
#   7070.2927318   7070.31047264]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:23:16.276.fits
# [ 4959.27492571  4959.28980114  4959.30467657 ...,  7070.27225216
#   7070.2899713   7070.30769043]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:23:16.285.fits
# [ 4959.27492571  4959.28980114  4959.30467657 ...,  7070.27225216
#   7070.2899713   7070.30769043]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:23:16.289.fits
# [ 4959.27492571  4959.28980114  4959.30467657 ...,  7070.27225216
#   7070.2899713   7070.30769043]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:34:03.087.fits
# [ 4959.27127612  4959.28614636  4959.30101661 ...,  7070.26965529
#   7070.28738891  7070.30512252]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:34:03.093.fits
# [ 4959.27127612  4959.28614636  4959.30101661 ...,  7070.26965529
#   7070.28738891  7070.30512252]
# Spectrum range not inclusive of all regions:  Spectra/GJ821/ADP.2017-10-26T20:34:03.098.fits
# [ 4959.27127612  4959.28614636  4959.30101661 ...,  7070.26965529
#   7070.28738891  7070.30512252]
# Average S:  0.372913031289 Error:  0.0080022470369
# Average log(R'HK):  -5.60224457648 Error:  0.0457533645387
# GJ191
# Low signal to noise (0.4): Spectra/GJ191/ADP.2014-10-06T10:06:54.180.fits
# Average S:  0.447404222226 Error:  0.000286448520833
# Average log(R'HK):  -5.35748505732 Error:  0.00673837973607
# LHS26
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# LHS353
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ754.1B
# Spectra/GJ754.1B/ADP.2014-09-24T09:41:38.493.fits  K flux negative:  -1.31472
# Average S:  0.725442 Error:  0.952557604302
# Average log(R'HK):  -5.18920974062 Error:  0.831098618339
# GJ388
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-05-17T09:58:42.127.fits
# [ 4726.18122654  4726.19547743  4726.20972833 ...,  6834.66184128
#   6834.67867708  6834.69551288]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.342.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.347.fits
# [ 3043.2121582   3043.23681641  3043.26123047 ...,  3915.95214844
#   3915.97680664  3916.0012207 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.350.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.354.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.356.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.361.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.365.fits
# [ 3043.2121582   3043.23681641  3043.26123047 ...,  3915.95214844
#   3915.97680664  3916.0012207 ]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:35:29.371.fits
# [ 4583.31689453  4583.34472656  4583.37255859 ...,  6686.07568359
#   6686.109375    6686.14257812]
# Low signal to noise (3.9158): Spectra/GJ388/ADP.2017-10-25T08:35:29.383.fits
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.406.fits
# [ 4583.27783203  4583.30566406  4583.33349609 ...,  6686.08544922
#   6686.11914062  6686.15234375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.411.fits
# [ 4583.27783203  4583.30566406  4583.33349609 ...,  6686.08544922
#   6686.11914062  6686.15234375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.414.fits
# [ 4583.27783203  4583.30566406  4583.33349609 ...,  6686.08544922
#   6686.11914062  6686.15234375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.421.fits
# [ 4583.27783203  4583.30566406  4583.33349609 ...,  6686.08544922
#   6686.11914062  6686.15234375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.422.fits
# [ 3043.20166016  3043.22631836  3043.25073242 ...,  3915.94677734
#   3915.97143555  3915.99609375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.425.fits
# [ 4583.27783203  4583.30566406  4583.33349609 ...,  6686.08544922
#   6686.11914062  6686.15234375]
# Spectrum range not inclusive of all regions:  Spectra/GJ388/ADP.2017-10-25T08:46:01.445.fits
# [ 3043.20166016  3043.22631836  3043.25073242 ...,  3915.94677734
#   3915.97143555  3915.99609375]
# Average S:  2.98785087016 Error:  0.000793491610743
# Average log(R'HK):  -4.71127778347 Error:  0.0162243042217
# GJ803
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2013-09-27T15:22:54.410.fits
# [ 4726.6625722   4726.69100017  4726.71942815 ...,  6834.69653936
#   6834.73035825  6834.76417715]
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2013-09-27T15:22:54.530.fits
# [ 4726.6625722   4726.69100017  4726.71942815 ...,  6834.69653936
#   6834.73035825  6834.76417715]
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2013-09-28T06:27:22.123.fits
# [ 4726.26128449  4726.28967931  4726.31807413 ...,  6834.80048569
#   6834.83444592  6834.86840614]
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2017-10-26T17:32:36.129.fits
# [ 5708.54656264  5708.56425593  5708.58194922 ...,  9463.24358969
#   9463.26705334  9463.290517  ]
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2017-10-26T17:32:36.130.fits
# [ 5708.54656264  5708.56425593  5708.58194922 ...,  9463.24358969
#   9463.26705334  9463.290517  ]
# Spectrum range not inclusive of all regions:  Spectra/GJ803/ADP.2017-10-26T17:32:36.135.fits
# [ 5708.54656264  5708.56425593  5708.58194922 ...,  9463.24358969
#   9463.26705334  9463.290517  ]
# Average S:  3.09731665038 Error:  0.00025394706122
# Average log(R'HK):  -4.37163841232 Error:  0.00794538253034
# GJ873
# Spectra/GJ873/HI.20020918.25418_0.fits  V flux negative:  -3930092.93498
# Spectra/GJ873/HI.20020918.25418_0.fits  S INDEX negative:  -0.0048083833893
# Spectra/GJ873/HI.20080908.42933_1.fits  K flux negative:  -2.58026434037e+12
# Average S:  3.02268498488 Error:  5.3668552336e-05
# Average log(R'HK):  -4.85749216871 Error:  0.0272711153838
# GJ551
# V-K out of valid spectral range:  6.74600028992
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ1132
# Low signal to noise (0.1): Spectra/GJ1132/ADP.2015-06-16T09:24:22.447.fits
# Low signal to noise (4.35): Spectra/GJ1132/ADP.2015-06-18T12:19:58.893.fits
# Low signal to noise (2.55): Spectra/GJ1132/ADP.2015-07-09T23:55:32.977.fits
# Low signal to noise (2.25): Spectra/GJ1132/ADP.2015-07-15T23:55:42.657.fits
# Low signal to noise (4.35): Spectra/GJ1132/ADP.2015-07-16T23:55:28.613.fits
# Low signal to noise (4.35): Spectra/GJ1132/ADP.2015-07-19T23:55:45.613.fits
# Low signal to noise (2.8): Spectra/GJ1132/ADP.2015-10-25T02:00:47.973.fits
# Spectra/GJ1132/ADP.2016-01-05T01:03:17.613.fits  K flux negative:  -0.383458
# Low signal to noise (4.8): Spectra/GJ1132/ADP.2016-05-26T01:01:25.885.fits
# Low signal to noise (2.65): Spectra/GJ1132/ADP.2016-06-28T01:02:37.320.fits
# Low signal to noise (3.2): Spectra/GJ1132/ADP.2016-12-11T01:00:58.131.fits
# Low signal to noise (3.35): Spectra/GJ1132/ADP.2017-05-03T01:01:26.700.fits
# Average S:  0.753906277788 Error:  0.0479251780146
# Average log(R'HK):  -5.58413086366 Error:  0.0558688820328
# GJ3470
# Low signal to noise (4.35): Spectra/GJ3470/ADP.2014-09-18T12:13:01.433.fits
# Low signal to noise (3.0): Spectra/GJ3470/ADP.2014-09-25T15:32:59.357.fits
# Low signal to noise (4.75): Spectra/GJ3470/ADP.2014-09-25T15:34:14.150.fits
# Low signal to noise (4.7): Spectra/GJ3470/ADP.2014-09-26T16:52:28.887.fits
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.217.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.63751351
#   6834.67157464  6834.70563576]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.230.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.60345238
#   6834.63751351  6834.67157464]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.237.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.60345238
#   6834.63751351  6834.67157464]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.250.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.63751351
#   6834.67157464  6834.70563576]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.270.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.60345238
#   6834.63751351  6834.67157464]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.277.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.63751351
#   6834.67157464  6834.70563576]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.290.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.63751351
#   6834.67157464  6834.70563576]
# Spectrum range not inclusive of all regions:  Spectra/GJ3470/ADP.2016-02-15T10:49:31.330.fits
# [ 4726.20007625  4726.22848539  4726.25689452 ...,  6834.60345238
#   6834.63751351  6834.67157464]
# ...
# Low signal to noise (3.05): Spectra/GJ3053/ADP.2016-07-15T01:01:52.437.fits
# Low signal to noise (2.8): Spectra/GJ3053/ADP.2016-08-07T01:02:22.696.fits
# Low signal to noise (3.3): Spectra/GJ3053/ADP.2016-08-07T01:02:22.700.fits
# Low signal to noise (4.35): Spectra/GJ3053/ADP.2016-08-09T01:03:45.553.fits
# Low signal to noise (4.35): Spectra/GJ3053/ADP.2016-08-09T01:03:45.557.fits
# Low signal to noise (3.8): Spectra/GJ3053/ADP.2016-09-12T07:26:55.154.fits
# Low signal to noise (3.25): Spectra/GJ3053/ADP.2016-09-12T07:26:55.160.fits
# Low signal to noise (4.4): Spectra/GJ3053/ADP.2016-09-14T01:03:04.915.fits
# Low signal to noise (4.75): Spectra/GJ3053/ADP.2016-10-02T01:02:55.825.fits
# Low signal to noise (4.6): Spectra/GJ3053/ADP.2016-10-14T01:01:26.167.fits
# Low signal to noise (3.05): Spectra/GJ3053/ADP.2016-10-20T01:01:22.619.fits
# Low signal to noise (3.2): Spectra/GJ3053/ADP.2016-10-20T01:01:22.625.fits
# Low signal to noise (4.55): Spectra/GJ3053/ADP.2016-10-22T01:01:37.561.fits
# Low signal to noise (0.0): Spectra/GJ3053/ADP.2016-10-26T01:01:22.361.fits
# Low signal to noise (4.4): Spectra/GJ3053/ADP.2016-10-27T01:01:03.330.fits
# Low signal to noise (3.2): Spectra/GJ3053/ADP.2016-10-27T01:01:03.332.fits
# Low signal to noise (4.45): Spectra/GJ3053/ADP.2016-11-10T01:01:43.034.fits
# Low signal to noise (4.25): Spectra/GJ3053/ADP.2016-12-13T01:02:00.034.fits
# Low signal to noise (4.35): Spectra/GJ3053/ADP.2016-12-30T01:01:46.089.fits
# Low signal to noise (3.9): Spectra/GJ3053/ADP.2016-12-30T01:01:46.095.fits
# Average S:  0.736586349465 Error:  0.156431283802
# Average log(R'HK):  -5.65596865623 Error:  0.163822715506
# TRAPPIST-1
# V-K out of valid spectral range:  8.50200080872
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ676A
# Average S:  0.696236386623 Error:  0.0013217093759
# Average log(R'HK):  -5.01379125353 Error:  0.00771867465611
# GJ15A
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ649
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ163
# Low signal to noise (2.8): Spectra/GJ163/ADP.2014-09-23T11:00:49.620.fits
# Low signal to noise (2.0): Spectra/GJ163/ADP.2014-09-23T11:01:31.183.fits
# Low signal to noise (0.4): Spectra/GJ163/ADP.2014-09-26T16:51:24.700.fits
# Low signal to noise (1.9): Spectra/GJ163/ADP.2014-09-26T16:51:39.117.fits
# Low signal to noise (2.85): Spectra/GJ163/ADP.2014-09-26T16:52:17.783.fits
# Low signal to noise (3.55): Spectra/GJ163/ADP.2014-09-26T16:53:07.233.fits
# Average S:  0.524661168794 Error:  0.00576003052707
# Average log(R'HK):  -5.6160213264 Error:  0.0203841389761
# GJ849
# Average S:  0.625062111927 Error:  0.00196267917518
# Average log(R'HK):  -5.51451147857 Error:  0.0288989429001
# GJ674
# Average S:  0.775571797947 Error:  0.000485694542999
# Average log(R'HK):  -5.28397289229 Error:  0.00823405857968
# GJ699
# Spectra/GJ699/ADP.2014-10-06T10:07:46.237.fits  K flux negative:  -1.34936
# Average S:  0.64520928131 Error:  0.00210530033458
# Average log(R'HK):  -5.63234623529 Error:  0.0253501836189
# L980-5
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# LP756-18
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# LHS2686
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ729
# Low signal to noise (0.95): Spectra/GJ729/ADP.2017-09-04T01:01:08.669.fits
# Average S:  2.64494903409 Error:  0.00910264013064
# Average log(R'HK):  -4.86461049253 Error:  0.0168540614432
# K2-3
# Low signal to noise (0.8): Spectra/K2-3/ADP.2015-07-01T08:16:54.257.fits
# Low signal to noise (3.95): Spectra/K2-3/ADP.2016-03-08T01:02:12.710.fits
# Average S:  0.465768212526 Error:  0.00994953217622
# Average log(R'HK):  -5.22317640847 Error:  0.0186402105071
# Ross1044
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# Ross825
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ273
# Low signal to noise (4.25): Spectra/GJ273/ADP.2016-04-24T01:00:56.075.fits
# Low signal to noise (2.8): Spectra/GJ273/ADP.2016-04-27T07:09:04.812.fits
# Average S:  0.608135942143 Error:  0.000763924227674
# Average log(R'HK):  -5.69005668499 Error:  0.0157135400157
# GJ860A
# V-K out of valid spectral range:  11.4099998474
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ205
# Average S:  0.84472349893 Error:  0.00012829322517
# Average log(R'HK):  -5.01739695025 Error:  0.00648069860963
# GJ588
# Spectra/GJ588/ADP.2014-10-06T10:05:17.743.fits  K flux negative:  -0.767506
# Low signal to noise (0.0): Spectra/GJ588/ADP.2014-10-06T10:06:54.560.fits
# Average S:  0.604761837201 Error:  0.000921769631893
# Average log(R'HK):  -5.51696033282 Error:  0.0160984798219
# GJ338A
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ644A
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# GJ411
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.824.fits
# [ 3024.11148859  3024.12370934  3024.1359301  ...,  3884.06161014
#   3884.07383089  3884.08605165]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.828.fits
# [ 3024.11148859  3024.12370934  3024.1359301  ...,  3884.06161014
#   3884.07383089  3884.08605165]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.831.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.835.fits
# [  6650.00144816   6650.02165817   6650.04186817 ...,  10251.88917757
#   10251.91450852  10251.93983946]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.839.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.840.fits
# [  6650.00144816   6650.02165817   6650.04186817 ...,  10251.88917757
#   10251.91450852  10251.93983946]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.841.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.842.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.844.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.846.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.848.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.851.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.852.fits
# [  6650.00144816   6650.02165817   6650.04186817 ...,  10251.88917757
#   10251.91450852  10251.93983946]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.854.fits
# [  6650.00144816   6650.02165817   6650.04186817 ...,  10251.88917757
#   10251.91450852  10251.93983946]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.857.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.859.fits
# [  6650.00144816   6650.02165817   6650.04186817 ...,  10251.88917757
#   10251.91450852  10251.93983946]
# Spectrum range not inclusive of all regions:  Spectra/GJ411/ADP.2017-10-26T12:47:51.860.fits
# [ 4726.5910943   4726.60554279  4726.61999127 ...,  6834.66423892
#   6834.68154844  6834.69885796]
# Average S:  0.434043273473 Error:  0.000133000167765
# Average log(R'HK):  -5.53112133215 Error:  0.0812815286576
# 2MASSJ04483062+1623187
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04235911+1643178
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04251456+1858250
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04202761+1853499
# V-K out of valid spectral range:  -10.2150001526
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04172811+1454038
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ02564122+3522346
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ03553690+2118482
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ03555715+1825564
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ03581434+1237408
# V-K out of valid spectral range:  -10.9870004654
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04004493+1354227
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04062060+1901391
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04183382+1821529
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04262170+1800009
# V-K out of valid spectral range:  -10.2530002594
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04290015+1620467
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04214955+1929086
# V-K out of valid spectral range:  -11.6680002213
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04110642+1247481
# V-K out of valid spectral range:  -11.8400001526
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# 2MASSJ04254182+1900477
# V-K out of valid spectral range:  -10.1300001144
# Average S: nan Error: nan
# Average log(R'HK): nan Error: nan
# Star names:  ['GJ176' 'GJ667C' 'GJ581' 'GJ1214' 'GJ832' 'GJ876' 'GJ436' 'GJ628' 'GJ887'
#  'GJ1061' 'HD173739' 'GSC8056-0482' '2MASSJ02543316-5108313'
#  '2MASSJ02001277-0840516' 'G75-55' '2MASSJ22025453-6440441'
#  '2MASSJ00240899-6211042' '2MASSJ01521830-5950168' '2MASSJ03315564-4359135'
#  '2MASSJ23261069-7323498' '2MASSJ23285763-6802338' '2MASSJ00393579-3816584'
#  'GJ173' 'GJ3290' 'LP415-1619' 'LP5-282' '2MASSJ02001277-0840516'
#  '2MASSJ04223953+1816097' '2MASSJ04184702+1321585' 'TYC1265-1118-1'
#  '2MASSJ02125819-5851182' 'GJ3997' '2MASSJ22463471-7353504' 'GJ4334' 'GJ49'
#  'GJ871.1A' 'LP247-13' 'G80-21' 'CD-571054' 'CD-352722' 'GJ410' 'LP55-41'
#  'G249-11' 'G111-72' 'GJ213' 'GJ4304' 'GJ821' 'GJ191' 'LHS26' 'LHS353'
#  'GJ754.1B' 'GJ388' 'GJ803' 'GJ873' 'GJ551' 'GJ1132' 'GJ3470' 'K2-25'
#  'GJ1243' 'TWA13A' 'TWA13B' 'TWA7' 'LHS2065' 'LHS3003' 'GJ285' 'GJ752B'
#  'GJ644C' 'GJ3053' 'TRAPPIST-1' 'GJ676A' 'GJ15A' 'GJ649' 'GJ163' 'GJ849'
#  'GJ674' 'GJ699' 'L980-5' 'LP756-18' 'LHS2686' 'GJ729' 'K2-3' 'Ross1044'
#  'Ross825' 'GJ273' 'GJ860A' 'GJ205' 'GJ588' 'GJ338A' 'GJ644A' 'GJ411'
#  '2MASSJ04483062+1623187' '2MASSJ04235911+1643178' '2MASSJ04251456+1858250'
#  '2MASSJ04202761+1853499' '2MASSJ04172811+1454038' '2MASSJ02564122+3522346'
#  '2MASSJ03553690+2118482' '2MASSJ03555715+1825564' '2MASSJ03581434+1237408'
#  '2MASSJ04004493+1354227' '2MASSJ04062060+1901391' '2MASSJ04183382+1821529'
#  '2MASSJ04262170+1800009' '2MASSJ04290015+1620467' '2MASSJ04214955+1929086'
#  '2MASSJ04110642+1247481' '2MASSJ04254182+1900477']
# S averages for each star:  [0.74245976188826446, 0.30326213843581806, 0.51507840449650799, 0.59700756877375094, 0.48846980135426421, 0.68685950339110291, 0.51043927900127128, 0.62948229042716386, 0.58022688894250485, 1.0862883273413566, 0.18848920737699262, 4.21814, 'nan', 'nan', 'nan', 'nan', 2.4630972508525542, 2.9858169569735651, 1.71946, 3.1769962911346785, 'nan', 'nan', 0.4963952701172557, 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 0.93868957491547311, 'nan', 'nan', 'nan', 'nan', 1.0485029069715923, 4.714591104295037, 'nan', 3.6307685797395584, 2.1220077894599041, 3.0708299999999999, 1.4123417845918611, 'nan', 'nan', 'nan', 0.84283008024518491, 0.63886461935661421, 0.3729130312887714, 0.4474042222263202, 'nan', 'nan', 0.72544200000000003, 2.9878508701620961, 3.0973166503832519, 3.0226849848795778, 'nan', 0.75390627778762198, 0.7299423416930636, 'nan', 'nan', 3.9555113399991706, 3.2834033065080921, 4.5524708592201675, 'nan', 'nan', 0.36186183184215875, 'nan', 'nan', 0.73658634946496548, 'nan', 0.69623638662294907, 'nan', 'nan', 0.52466116879351066, 0.62506211192707783, 0.77557179794673003, 0.64520928131018951, 'nan', 'nan', 'nan', 2.6449490340907276, 0.4657682125257861, 'nan', 'nan', 0.60813594214270217, 'nan', 0.84472349892981335, 0.60476183720095511, 'nan', 'nan', 0.4340432734729015, 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# R'HK averages for each star:  [5.8429298178831238e-06, 3.0388335146041994e-06, 2.1309468979751441e-06, 8.3103699007160128e-07, 3.6355699600755899e-06, 2.2198865290969911e-06, 2.7074963425768781e-06, 2.1020742008620417e-06, 6.9005410619392071e-06, 1.1077511963693438e-06, 6.8422024802689154e-08, 2.9159592834899999e-05, 'nan', 'nan', 'nan', 'nan', 4.3275059617033039e-05, 3.1420596108914259e-05, 4.0545378881900001e-05, 5.122403902734636e-05, 'nan', 'nan', 3.526630562983362e-06, 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 1.3239204066434332e-05, 'nan', 'nan', 'nan', 'nan', 9.31244129014996e-06, 2.6266022569404894e-05, 'nan', 3.2084608911183336e-05, 3.7777549962474278e-05, 4.50815575121e-05, 2.1498153226571073e-05, 'nan', 'nan', 'nan', 1.560484028278616e-06, 7.024921985074034e-06, 2.4989376682484269e-06, 4.3905097171675094e-06, 'nan', 'nan', 6.4683015650999991e-06, 1.9441161880962152e-05, 4.2497324363187876e-05, 1.3883783452267089e-05, 'nan', 2.6053683698393656e-06, 6.0435766025898853e-06, 'nan', 'nan', 5.8942681220273224e-05, 3.0618621440068361e-05, 7.4423046683701232e-05, 'nan', 'nan', -1.3699643666038234e-07, 'nan', 'nan', 2.2081640942070761e-06, 'nan', 9.6874337719052059e-06, 'nan', 'nan', 2.4209101629755132e-06, 3.0583594118376885e-06, 5.2002845455219791e-06, 2.3315984863474627e-06, 'nan', 'nan', 'nan', 1.365807544832996e-05, 5.9816857232263313e-06, 'nan', 'nan', 2.0414714703106662e-06, 'nan', 9.6073375503438619e-06, 3.0411627838770137e-06, 'nan', 'nan', 2.9435991432417809e-06, 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# log(R'HK) averages for each star:  [-5.23336933 -5.51729309 -5.67142737 -6.08037965 -5.43942749 -5.65366922
#  -5.56743212 -5.67735196 -5.16111686 -5.95555777 -7.16480408 -4.53521854
#         -inf        -inf        -inf        -inf -4.36376233 -4.50278558
#  -4.39205864 -4.29052618        -inf        -inf -5.45264003        -inf
#         -inf        -inf        -inf        -inf        -inf -4.87813812
#         -inf        -inf        -inf        -inf -5.03093645 -4.58060569
#         -inf -4.49370325 -4.42276621 -4.34600109 -4.66759885        -inf
#         -inf        -inf -5.80674067 -5.15335849 -5.60224458 -5.35748506
#         -inf        -inf -5.18920974 -4.71127778 -4.37163841 -4.85749217
#         -inf -5.58413086 -5.21870597        -inf        -inf -4.22957011
#  -4.51401437 -4.12829256        -inf        -inf         nan        -inf
#         -inf -5.65596866        -inf -5.01379125        -inf        -inf
#  -5.61602133 -5.51451148 -5.28397289 -5.63234624        -inf        -inf
#         -inf -4.86461049 -5.22317641        -inf        -inf -5.69005668
#         -inf -5.01739695 -5.51696033        -inf        -inf -5.53112133
#         -inf        -inf        -inf        -inf        -inf        -inf
#         -inf        -inf        -inf        -inf        -inf        -inf
#         -inf        -inf        -inf        -inf        -inf]
# /Users/katiemel/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:405: RuntimeWarning: divide by zero encountered in log10
# /Users/katiemel/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:405: RuntimeWarning: invalid value encountered in log10

# %%
print(all_S[non_nan].shape)
print(all_err_S[non_nan].shape)
print(func_var_RHK)
print(len(short_stars_photometry))
V = short_stars_photometry[:,2]
K = short_stars_photometry[:,0]
# Out:
# (85,)
# (85,)
# [  1.33215620e-12]
# 107

# %%
output = np.column_stack((np.nan_to_num(np.array(stars_S_avgs).astype("float")), 
                          np.nan_to_num(np.array(stars_S_avgs_err).astype("float")), 
                          np.nan_to_num(np.array(stars_RHK_PRIME_avgs).astype("float")),
                          np.nan_to_num(np.array(stars_RHK_PRIME_avgs_err).astype("float")),
                          np.nan_to_num(np.array(log_stars_S_avgs).astype("float")), 
                          np.nan_to_num(np.array(log_stars_S_avgs_err).astype("float")), 
                          np.nan_to_num(np.array(log_stars_RHK_PRIME_avgs).astype("float")),
                          np.nan_to_num(np.array(log_stars_RHK_PRIME_avgs_err).astype("float"))))
#print(output)
np.savetxt("Results/cahk_s_rhk.txt", output)

# %%
#print(wave[K_idx_wave])

K = 3933.6614
H = 3968.4673

#x=[6562.8-0.24312788/2, 6562.8+0.24312788/2, 6562.8+0.24312788/2, 6562.8-0.24312788/2]
#y=[mean_cont, mean_cont, 0, 0]

fig = plt.figure(figsize=(12,6))
fig.text(0.08, 0.5, 'Flux (erg cm$^{-2}$ s$^{-1}$ \AA$^{-1}$)', ha='center', va='center', rotation='vertical', fontsize=18)

plt.subplot(211)
plt.xlim(3890,3935)
plt.plot(wave, flux/np.max(K_sub_flux), color="cornflowerblue")
plt.ylim(-0.1,1.19)
plt.plot((3891, 3911), (1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((3891, 3891), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((3911, 3911), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.text(3901, 1.05, "V", fontsize=14)
plt.plot((K-1.09/2, K+1.09/2), (1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((K+1.09/2, K+1.09/2), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((K-1.09/2, K-1.09/2), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.text(wave[K_idx_wave][np.argmax(K_sub_flux)], 1.05, "K", fontsize=14)
plt.title(r"CaII HK Peaks and Continuum Regions of GJ176", fontsize=20)

plt.subplot(212)
plt.xlim(3965,4015)
plt.plot(wave, flux/np.max(H_sub_flux), color="cornflowerblue")
plt.ylim(-0.1,1.19)
plt.plot((3991, 4011), (1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((3991, 3991), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((4011, 4011), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.text(4001, 1.05, "R", fontsize=14)
plt.plot((H-1.09/2, H+1.09/2), (1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((H+1.09/2, H+1.09/2), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.plot((H-1.09/2, H-1.09/2), (-0.1, 1), linewidth=2, color = 'green', linestyle="--")
plt.text(wave[H_idx_wave][np.argmax(H_sub_flux)], 1.05, "H", fontsize=14)
plt.xlabel(r"Wavelength (\AA)", fontsize=18)

#plt.savefig("Comparisons/POSTER_CaHK_example.png")
plt.show()

# %%
print(wave)

# %%
wave = hdu[1].data
#print(wave)
#print(K_idx_wave)
flux = hdu[1].data
#print(wave, flux)
print(len(flux))
print(spectra[i])
print(V_idx_cont[0])
hdu[1].info

# %% [markdown]
# # HARPS AND HIRES (before coadding the spectra!)

# %%
stars_S_avgs = []
stars_S_avgs_err = []
stars_RHK_PRIME_avgs = []
stars_RHK_PRIME_avgs_err = []

#star_names = ["TYC1265-1118-1"]
#star_names = ["2MASSJ04184702+1321585"]
#star_names = ["GJ176"]

for j in range(len(star_names)):
    print(star_names[j])
    
    #calculating stellar ccf (Astudillo-Defru 2017 equation 9 and table 1)
    #ALL COEFFS ARE FOR V-K COLOR
    ccf_c0 = -0.005
    ccf_c1 = 0.071
    ccf_c2 = -0.713 # +/- 0.006
    ccf_c3 = 0.973 # +/- 0.006
    
    R_c0 = -0.003
    R_c1 = 0.069
    R_c2 = -0.717 # +/- 0.003
    R_c3 = -3.498 # +/- 0.004
    
    V = short_stars_photometry[j][2]
    V_err = short_stars_photometry[j][3]
    K = short_stars_photometry[j][0]
    K_err = short_stars_photometry[j][1]
    V_K = V-K

    #QUESTION: should "log" in the paper mean natural log???
    Ccf = 10**(ccf_c0*(V_K)**3 + ccf_c1*(V_K)**2 + ccf_c2*(V_K) + ccf_c3)
    Rphot = 10**(R_c0*(V_K)**3 + R_c1*(V_K)**2 + R_c2*(V_K) + R_c3)
    #print(Rphot)

    spectra = sorted(glob.glob("Spectra/%s/*.fits" % star_names[j]))
    #print(spectrum)
    
    #speed of light, target star RV in meters per second
    c = 299792458e10
    RV = short_stars_rv[j] * (10**13)

    all_S = []
    all_RHK_PRIME = []
    all_err_S = []
    all_err_RHK_PRIME = []

    for i in range(len(spectra)): #range(0,55):
        
        if "ADP" in spectra[i]:
            hdu = pyfits.open(spectra[i])
            #print(spectra[i])
            #print(i)

            wave = hdu[1].data[0][0] 
            flux = hdu[1].data[0][1]
            err = np.nan_to_num(hdu[1].data[0][2])
            #print("HARPS Error Array: ", err)

            wave = wave / (1 + RV / c)

            #fnding mean V continuum flux
            V_idx_cont = np.where((wave > (3901 - 10)) & (wave < (3901 + 10)))
            V_sub_cont = flux[V_idx_cont]
            V_err_cont = np.std(V_sub_cont)
            V_mean_cont = np.mean(V_sub_cont)

            #finding mean K line flux
            K_idx_wave = np.array(np.where((wave > (3933.6614 - 1.09/.5)) & (wave < (3933.6614 + 1.09/.5))))
            K_sub_flux = flux[K_idx_wave]
            K_err_flux = err[K_idx_wave] 
            K_mean_flux = np.mean(K_sub_flux)

            #finding mean H line flux
            H_idx_wave = np.array(np.where((wave > (3968.4673 - 1.09/.5)) & (wave < (3968.4673 + 1.09/.5))))
            H_sub_flux = flux[H_idx_wave]
            H_err_flux = err[H_idx_wave] 
            H_mean_flux = np.mean(H_sub_flux)

            #finding mean R continuum flux                      
            R_idx_cont = np.where(((wave > (4001 - 10)) & (wave < (4001 + 10))))
            R_sub_cont = flux[R_idx_cont]
            R_err_cont = np.std(R_sub_cont)
            R_mean_cont = np.mean(R_sub_cont)
            
            #S INDEX!!!
            S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
            S = S_instrument_calibrated
            
            #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
            Rhk = 1.887e-4 * Ccf * S
            #print(Rhk)
            RHK_PRIME = Rhk - Rphot
            #print(RHK_PRIME)
            
            """plt.figure(figsize=(16,4))
            plt.plot(wave,flux)
            #plt.xlim(3880,4020)
            plt.xlim(3920,3940)
            #plt.xlim(3925,3975)
            plt.ylim(-100,1000)
            plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
            plt.axvline(3968.4673 + 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3968.4673 - 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
            plt.axvline(3933.6614 + 1.09/2) # + 3933.6614 * RV / c )
            plt.axvline(3933.6614 - 1.09/2) # + 3933.6614 * RV / c )
            plt.show()"""
            
            #TESTING FOR NOISY SPECTRA
            if H_mean_flux < 0.0:
                print(spectra[i], " H flux negative: ", H_mean_flux)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            if K_mean_flux < 0.0:
                print(spectra[i], " K flux negative: ", K_mean_flux)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            if V_mean_cont < 0.0:
                print(spectra[i], " V flux negative: ", V_mean_cont)
            if R_mean_cont < 0.0:
                print(spectra[i], " R flux negative: ", R_mean_cont)
            if S < 0.0:
                print(spectra[i], " S INDEX negative: ", S)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            
            #TESTING FOR RANGES (PARTICULARLY FOR UVES)
            if (np.min(wave)>3891 or np.max(wave)<4011):
                print("Spectrum range not inclusive of all regions: ", spectra[i])
                print(wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
            else:
                func_var_S = np.array([(R_err_cont**2)*((1/R_mean_cont**2)**2)+(V_err_cont**2)*((1/V_mean_cont**2)**2)])
                err_S = np.sqrt(np.sum(func_var_S))
                func_var_RHK = 1.884e-4 * (err_S**2) * Ccf #technically need to include Ccf error too!!!!!
                err_RHK_PRIME = np.sqrt(np.sum(func_var_RHK))
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)

        #######################################################################
        
        #HIRES TARGET SPECTRA
        if "HI" in spectra[i]:
            V_file = glob.glob("%s/HI.*_03_flux.fits" % spectra[i])
            HK_file = glob.glob("%s/HI.*_04_flux.fits" % spectra[i])
            R_file = glob.glob("%s/HI.*_05_flux.fits" % spectra[i])

            V_hdu = pyfits.open(V_file[0])
            HK_hdu = pyfits.open(HK_file[0])
            R_hdu = pyfits.open(R_file[0])

            V_wave = V_hdu[1].data["wave"] / (1 + RV / c)
            V_flux = V_hdu[1].data["flux"]
            
            HK_wave = HK_hdu[1].data["wave"] / (1 + RV / c)
            HK_flux = HK_hdu[1].data["flux"]

            R_wave = R_hdu[1].data["wave"] / (1 + RV / c)
            R_flux = R_hdu[1].data["flux"]
            
            #fnding mean V continuum flux
            V_idx_cont = np.where((V_wave > (3901 - 10)) & (V_wave < (3901 + 10)))
            V_sub_cont = flux[V_idx_cont]
            V_err_cont = np.std(V_sub_cont)
            V_mean_cont = np.mean(V_sub_cont)

            #finding mean K line flux
            K_idx_wave = np.array(np.where((HK_wave > (3933.6614 - 1.09/.5)) & (HK_wave < (3933.6614 + 1.09/.5))))
            K_sub_flux = flux[K_idx_wave]
            K_err_flux = err[K_idx_wave] 
            K_mean_flux = np.mean(K_sub_flux)

            #finding mean H line flux
            H_idx_wave = np.array(np.where((HK_wave > (3968.4673 - 1.09/.5)) & (HK_wave < (3968.4673 + 1.09/.5))))
            H_sub_flux = flux[H_idx_wave]
            H_err_flux = err[H_idx_wave] 
            H_mean_flux = np.mean(H_sub_flux)

            #finding mean R continuum flux                      
            R_idx_cont = np.where(((R_wave > (4001 - 10)) & (R_wave < (4001 + 10))))
            R_sub_cont = flux[R_idx_cont]
            R_err_cont = np.std(R_sub_cont)
            R_mean_cont = np.mean(R_sub_cont)
            
            #S INDEX!!!
            S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
            S = S_instrument_calibrated

            #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
            Rhk = 1.887e-4 * Ccf * S
            #print(Rhk)
            RHK_PRIME = Rhk - Rphot
            #print(RHK_PRIME)

            #TESTING FOR NOISY SPECTRA
            if H_mean_flux < 0.0:
                print(spectra[i], " H flux negative: ", H_mean_flux)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            if K_mean_flux < 0.0:
                print(spectra[i], " K flux negative: ", K_mean_flux)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            if V_mean_cont < 0.0:
                print(spectra[i], " V flux negative: ", V_mean_cont)
            if R_mean_cont < 0.0:
                print(spectra[i], " R flux negative: ", R_mean_cont)
            if S < 0.0:
                print(spectra[i], " S INDEX negative: ", S)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
            
            #TESTING FOR RANGES
            if (np.min(V_wave)>3891 or np.max(V_wave)<3911):
                print("03 Spectrum range not inclusive of all regions: ", spectra[i])
                print(V_wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
            if (np.min(HK_wave)>3932 or np.max(HK_wave)<3970):
                print("04 Spectrum range not inclusive of all regions: ", spectra[i])
                print(HK_wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
            if (np.min(R_wave)>3991 or np.max(R_wave)<4011):
                print("05 Spectrum range not inclusive of all regions: ", spectra[i])
                print(R_wave)
                S = "nan"
                RHK_PRIME = "nan"
                err_S = "nan"
                err_RHK_PRIME = "nan"
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)
            else:
                func_var_S = np.array([(R_err_cont**2)*((1/R_mean_cont**2)**2)+(V_err_cont**2)*((1/V_mean_cont**2)**2)])
                err_S = np.sqrt(np.sum(func_var_S))
                func_var_RHK = 1.884e-4 * (err_S**2) * Ccf #technically need to include Ccf error too!!!!!
                err_RHK_PRIME = np.sqrt(np.sum(func_var_RHK))
                all_S.append(S)
                all_RHK_PRIME.append(RHK_PRIME)
                all_err_S.append(err_S)
                all_err_RHK_PRIME.append(err_RHK_PRIME)

    #AVERAGING CALCULATED INDEX VALUES FOR EACH STAR
    #stars_S_avgs.append(np.nanmean(np.array(all_S).astype("float")))
    #stars_S_avgs_err.append(np.nanstd(np.array(all_S).astype("float"), ddof=1))
    #stars_RHK_PRIME_avgs.append(np.nanmean(np.array(all_RHK_PRIME).astype("float")))
    #stars_RHK_PRIME_avgs_err.append(np.nanstd(np.array(all_RHK_PRIME).astype("float"), ddof=1))

    non_nan = np.where(np.logical_not(np.logical_and(np.isnan(np.array(all_S).astype("float")), 
                                                     np.isnan(np.array(all_RHK_PRIME).astype("float")))))[0]
    #non_nan_RHK = np.where(np.logical_not(np.isnan(all_RHK_PRIME)))[0]
    all_S = np.array(all_S).astype("float")
    all_RHK_PRIME = np.array(all_RHK_PRIME).astype("float")
    all_err_S = np.array(all_err_S).astype("float")
    all_err_RHK_PRIME = np.array(all_err_RHK_PRIME).astype("float")
    
    if len(non_nan) != 0:
        stars_S_avgs.append(np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2))) #np.nanmean takes average while ignoring nan
        stars_S_avgs_err.append(1/np.sum(1/((all_err_S[non_nan])**2)))
        stars_RHK_PRIME_avgs.append(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2)))
        stars_RHK_PRIME_avgs_err.append(1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2)))
        print("Average S: ", np.average(all_S[non_nan], weights=1/((all_err_S[non_nan])**2)),
              "Error: ", 1/np.sum(1/((all_err_S[non_nan])**2)))
        print("Average log(R'HK): ", np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))),
              "Error: ", (1/np.sum(1/((all_err_RHK_PRIME[non_nan])**2)))/np.log10(np.average(all_RHK_PRIME[non_nan], weights=1/((all_err_RHK_PRIME[non_nan])**2))))
    else:
        stars_S_avgs.append("nan") #np.nanmean takes average while ignoring nan
        stars_S_avgs_err.append("nan")
        stars_RHK_PRIME_avgs.append("nan")
        stars_RHK_PRIME_avgs_err.append("nan")
        print("Average S: nan", "Error: nan")
        print("Average log(R'HK): nan", "Error: nan")
        
print("Star names: ", star_names)
print("S averages for each star: ", stars_S_avgs)
print("R'HK averages for each star: ", stars_RHK_PRIME_avgs)
print("log(R'HK) averages for each star: ", np.log10(np.nan_to_num(np.array(stars_RHK_PRIME_avgs).astype("float"))))

# %% [markdown]
# # HARPS ONLY

# %%
star_names = np.genfromtxt("short_star_names.txt", dtype='str')

short_stars_rv = np.loadtxt("short_RVs.txt")
short_stars_photometry = np.loadtxt("short_photometry.txt")
#print(short_stars_rv)

stars_S_avgs = []
stars_S_avgs_err = []
stars_RHK_PRIME_avgs = []
stars_RHK_PRIME_avgs_err = []

for j in range(len(star_names)):
    
    #calculating stellar ccf (Astudillo-Defru 2017 equation 9 and table 1)
    #ALL COEFFS ARE FOR V-K COLOR
    ccf_c0 = -0.005
    ccf_c1 = 0.071
    ccf_c2 = -0.713 # +/- 0.006
    ccf_c3 = 0.973 # +/- 0.006
    
    R_c0 = -0.003
    R_c1 = 0.069
    R_c2 = -0.717 # +/- 0.003
    R_c3 = -3.498 # +/- 0.004
    
    V = short_stars_photometry[j][2]
    V_err = short_stars_photometry[j][3]
    K = short_stars_photometry[j][0]
    K_err = short_stars_photometry[j][1]
    V_K = V-K

    #QUESTION: should "log" in the paper mean natural log???
    Ccf = 10**(ccf_c0*(V_K)**3 + ccf_c1*(V_K)**2 + ccf_c2*(V_K) + ccf_c3)
    Rphot = 10**(R_c0*(V_K)**3 + R_c1*(V_K)**2 + R_c2*(V_K) + R_c3)
    #print(Rphot)

    spectra = sorted(glob.glob("Spectra/%s/*.fits" % star_names[j]))
    #print(spectrum)

    all_S = []
    all_RHK_PRIME = []

    for i in range(len(spectra)):
        hdu = pyfits.open(spectra[i])

        wave = hdu[1].data[0][0] 
        flux = hdu[1].data[0][1]
        err = np.nan_to_num(hdu[1].data[0][2])
        #print("HARPS Error Array: ", err)

        #speed of light, target star RV, H-alpha in meters per second
        c = 299792458e10
        RV = short_stars_rv[j] * (10**13)
        
        wave = wave - (wave * RV / c)
        
        #THE FOLLOWING S INDEX IS BASED ON EQN 2 OF ASTUDILLO-DEFRU ET AL. 2017 (page 4)

        #fnding mean V continuum flux
        V_idx_cont = np.where((wave > (3901 - 10)) & (wave < (3901 + 10)))
        V_sub_cont = flux[V_idx_cont]
        V_err_cont = np.std(V_sub_cont)
        V_mean_cont = np.mean(V_sub_cont)
                              
        #finding mean K line flux
        K_idx_wave = np.array(np.where((wave > (3933.6614 - 1.09/.5)) & (wave < (3933.6614 + 1.09/.5))))
        K_sub_flux = flux[K_idx_wave]
        K_err_flux = err[K_idx_wave] 
        K_mean_flux = np.mean(K_sub_flux)
                              
        #finding mean H line flux
        H_idx_wave = np.array(np.where((wave > (3968.4673 - 1.09/.5)) & (wave < (3968.4673 + 1.09/.5))))
        H_sub_flux = flux[H_idx_wave]
        H_err_flux = err[H_idx_wave] 
        H_mean_flux = np.mean(H_sub_flux)
                                      
        #finding mean R continuum flux                      
        R_idx_cont = np.where(((wave > (4001 - 10)) & (wave < (4001 + 10))))
        R_sub_cont = flux[R_idx_cont]
        R_err_cont = np.std(R_sub_cont)
        R_mean_cont = np.mean(R_sub_cont)
                              
        #S INDEX!!!
        S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
        S = S_instrument_calibrated
        
        if H_mean_flux < 0.0:
            print(spectra[i], " H flux negative: ", H_mean_flux)
        if K_mean_flux < 0.0:
            print(spectra[i], " K flux negative: ", K_mean_flux)
        if V_mean_cont < 0.0:
            print(spectra[i], " V flux negative: ", V_mean_cont)
        if R_mean_cont < 0.0:
            print(spectra[i], " R flux negative: ", R_mean_cont)
        if S < 0.0:
            print(spectra[i], " S INDEX negative: ", S)
            #print(star_names[j])
            #print(RV)
            plt.figure(figsize=(16,4))
            plt.plot(wave,flux)
            #plt.xlim(3880,4020)
            #plt.xlim(3920,3940)
            plt.xlim(3925,3975)
            plt.ylim(-100,100)
            plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
            plt.axvline(3968.4673 + 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3968.4673 - 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
            plt.axvline(3933.6614 + 1.09/2) # + 3933.6614 * RV / c )
            plt.axvline(3933.6614 - 1.09/2) # + 3933.6614 * RV / c )
            plt.show()
        
        #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
        Rhk = 1.887e-4 * Ccf * S
        #print(Rhk)
        RHK_PRIME = Rhk - Rphot
        #print(RHK_PRIME)
        
        #COLLECTING INFO FOR ALL SPECTRA OF A SINGLE STAR
        all_S.append(S)
        all_RHK_PRIME.append(RHK_PRIME)
    
    #AVERAGING CALCULATED INDEX VALUES FOR EACH STAR
    stars_S_avgs.append(np.mean(all_S))
    stars_S_avgs_err.append(np.std(all_S, ddof=1))
    stars_RHK_PRIME_avgs.append(np.mean(all_RHK_PRIME))
    stars_RHK_PRIME_avgs_err.append(np.std(all_RHK_PRIME, ddof=1))
    
    print(star_names[j], RV)

print("Star names: ", star_names)
print("S averages for each star: ", stars_S_avgs)
print("R'HK averages for each star: ", stars_RHK_PRIME_avgs)
print("log(R'HK) averages for each star: ", np.log10(stars_RHK_PRIME_avgs))

# %%
print(star_names[j])
print(RV)
plt.figure(figsize=(16,4))
plt.plot(wave,flux)
#plt.xlim(3880,4020)
#plt.xlim(3920,3940)
plt.xlim(3900,3940)
plt.ylim(-100,500)
plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
plt.axvline(3968.4673 + 1.09/2) #+ 3968.4673 * RV / c )
plt.axvline(3968.4673 - 1.09/2) #+ 3968.4673 * RV / c )
plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
plt.axvline(3933.6614 + 1.09/2) #+ 3933.6614 * RV / c )
plt.axvline(3933.6614 - 1.09/2) #+ 3933.6614 * RV / c )

# %%
output = np.column_stack((stars_S_avgs, stars_S_avgs_err,  stars_RHK_PRIME_avgs, stars_RHK_PRIME_avgs_err))
np.savetxt("Results/short_cahk_s_rhk.txt", output)

# %% [markdown]
# # HIRES ONLY

# %%
star_names = np.genfromtxt("short_star_names.txt", dtype='str')

short_stars_rv = np.loadtxt("short_RVs.txt")
short_stars_photometry = np.loadtxt("short_photometry.txt")
#print(short_stars_rv)

stars_S_avgs = []
stars_S_avgs_err = []
stars_RHK_PRIME_avgs = []
stars_RHK_PRIME_avgs_err = []

for j in range(len(star_names)):
    
    #calculating stellar ccf (Astudillo-Defru 2017 equation 9 and table 1)
    #ALL COEFFS ARE FOR V-K COLOR
    ccf_c0 = -0.005
    ccf_c1 = 0.071
    ccf_c2 = -0.713 # +/- 0.006
    ccf_c3 = 0.973 # +/- 0.006
    
    R_c0 = -0.003
    R_c1 = 0.069
    R_c2 = -0.717 # +/- 0.003
    R_c3 = -3.498 # +/- 0.004
    
    V = short_stars_photometry[j][2]
    V_err = short_stars_photometry[j][3]
    K = short_stars_photometry[j][0]
    K_err = short_stars_photometry[j][1]
    V_K = V-K

    #QUESTION: should "log" in the paper mean natural log???
    Ccf = 10**(ccf_c0*(V_K)**3 + ccf_c1*(V_K)**2 + ccf_c2*(V_K) + ccf_c3)
    Rphot = 10**(R_c0*(V_K)**3 + R_c1*(V_K)**2 + R_c2*(V_K) + R_c3)
    #print(Rphot)

    spectra = sorted(glob.glob("Spectra/%s/*.fits" % star_names[j]))
    #print(spectrum)

    all_S = []
    all_RHK_PRIME = []

    for i in range(len(spectra)):
        hdu = pyfits.open(spectra[i])

        wave = hdu[1].data[0][0] 
        flux = hdu[1].data[0][1]
        err = np.nan_to_num(hdu[1].data[0][2])
        #print("HARPS Error Array: ", err)

        #speed of light, target star RV, H-alpha in meters per second
        c = 299792458e10
        RV = short_stars_rv[j] * (10**13)
        
        wave = wave - (wave * RV / c)
        
        #THE FOLLOWING S INDEX IS BASED ON EQN 2 OF ASTUDILLO-DEFRU ET AL. 2017 (page 4)

        #fnding mean V continuum flux
        V_idx_cont = np.where((wave > (3901 - 10)) & (wave < (3901 + 10)))
        V_sub_cont = flux[V_idx_cont]
        V_err_cont = np.std(V_sub_cont)
        V_mean_cont = np.mean(V_sub_cont)
                              
        #finding mean K line flux
        K_idx_wave = np.array(np.where((wave > (3933.6614 - 1.09/.5)) & (wave < (3933.6614 + 1.09/.5))))
        K_sub_flux = flux[K_idx_wave]
        K_err_flux = err[K_idx_wave] 
        K_mean_flux = np.mean(K_sub_flux)
                              
        #finding mean H line flux
        H_idx_wave = np.array(np.where((wave > (3968.4673 - 1.09/.5)) & (wave < (3968.4673 + 1.09/.5))))
        H_sub_flux = flux[H_idx_wave]
        H_err_flux = err[H_idx_wave] 
        H_mean_flux = np.mean(H_sub_flux)
                                      
        #finding mean R continuum flux                      
        R_idx_cont = np.where(((wave > (4001 - 10)) & (wave < (4001 + 10))))
        R_sub_cont = flux[R_idx_cont]
        R_err_cont = np.std(R_sub_cont)
        R_mean_cont = np.mean(R_sub_cont)
                              
        #S INDEX!!!
        S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
        S = S_instrument_calibrated
        
        if H_mean_flux < 0.0:
            print(spectra[i], " H flux negative: ", H_mean_flux)
        if K_mean_flux < 0.0:
            print(spectra[i], " K flux negative: ", K_mean_flux)
        if V_mean_cont < 0.0:
            print(spectra[i], " V flux negative: ", V_mean_cont)
        if R_mean_cont < 0.0:
            print(spectra[i], " R flux negative: ", R_mean_cont)
        if S < 0.0:
            print(spectra[i], " S INDEX negative: ", S)
            #print(star_names[j])
            #print(RV)
            plt.figure(figsize=(16,4))
            plt.plot(wave,flux)
            #plt.xlim(3880,4020)
            #plt.xlim(3920,3940)
            plt.xlim(3925,3975)
            plt.ylim(-100,100)
            plt.axvline(3968.4673) #+ 3968.4673 * RV / c )
            plt.axvline(3968.4673 + 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3968.4673 - 1.09/2) # + 3968.4673 * RV / c )
            plt.axvline(3933.6614) #+ 3933.6614 * RV / c )
            plt.axvline(3933.6614 + 1.09/2) # + 3933.6614 * RV / c )
            plt.axvline(3933.6614 - 1.09/2) # + 3933.6614 * RV / c )
            plt.show()
        
        #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
        Rhk = 1.887e-4 * Ccf * S
        #print(Rhk)
        RHK_PRIME = Rhk - Rphot
        #print(RHK_PRIME)
        
        #COLLECTING INFO FOR ALL SPECTRA OF A SINGLE STAR
        all_S.append(S)
        all_RHK_PRIME.append(RHK_PRIME)
    
    #AVERAGING CALCULATED INDEX VALUES FOR EACH STAR
    stars_S_avgs.append(np.mean(all_S))
    stars_S_avgs_err.append(np.std(all_S, ddof=1))
    stars_RHK_PRIME_avgs.append(np.mean(all_RHK_PRIME))
    stars_RHK_PRIME_avgs_err.append(np.std(all_RHK_PRIME, ddof=1))
    
    print(star_names[j], RV)

print("Star names: ", star_names)
print("S averages for each star: ", stars_S_avgs)
print("R'HK averages for each star: ", stars_RHK_PRIME_avgs)
print("log(R'HK) averages for each star: ", np.log10(stars_RHK_PRIME_avgs))

# %% [markdown]
# ## BELOW THIS DON'T CHANGE!

# %%
#OLD!!! KEEP THIS WAY!!

star_names = np.genfromtxt("short_star_names.txt", dtype='str')

short_stars_rv = np.loadtxt("short_RVs.txt")
short_stars_photometry = np.loadtxt("short_photometry.txt")
#print(short_stars_rv)

stars_S_avgs = []
stars_S_avgs_err = []
stars_RHK_PRIME_avgs = []
stars_RHK_PRIME_avgs_err = []

for j in range(len(star_names)):
    
    print(star_names[j])
    
    #calculating stellar ccf (Astudillo-Defru 2017 equation 9 and table 1)
    #ALL COEFFS ARE FOR V-K COLOR
    ccf_c0 = -0.005
    ccf_c1 = 0.071
    ccf_c2 = -0.713 # +/- 0.006
    ccf_c3 = 0.973 # +/- 0.006
    
    R_c0 = -0.003
    R_c1 = 0.069
    R_c2 = -0.717 # +/- 0.003
    R_c3 = -3.498 # +/- 0.004
    
    V = short_stars_photometry[j][2]
    V_err = short_stars_photometry[j][3]
    K = short_stars_photometry[j][0]
    K_err = short_stars_photometry[j][1]
    V_K = V-K

    #QUESTION: should "log" in the paper mean natural log???
    Ccf = 10**(ccf_c0*(V_K)**3 + ccf_c1*(V_K)**2 + ccf_c2*(V_K) + ccf_c3)
    Rphot = 10**(R_c0*(V_K)**3 + R_c1*(V_K)**2 + R_c2*(V_K) + R_c3)
    #print(Rphot)

    spectra = sorted(glob.glob("Spectra/%s/*.fits" % star_names[j]))
    #print(spectrum)

    all_S = []
    all_RHK_PRIME = []

    for i in range(len(spectra)):
        hdu = pyfits.open(spectra[i])

        wave = hdu[1].data[0][0] 
        flux = hdu[1].data[0][1]
        err = np.nan_to_num(hdu[1].data[0][2])
        #print("HARPS Error Array: ", err)

        #speed of light, target star RV, H-alpha in meters per second
        c = 299792458
        CaH = 3968e-10
        CaK = 3934e-10
        RV = short_stars_rv[j] * (10 ** 3)
        #RV_conv = 0
        RV_conv_H = (CaH * RV / c) * (10 ** 10)
        RV_conv_K = (CaK * RV / c) * (10 ** 10)
        
        #accounting for target star RV conversion in angstroms
        #RV given in SIMBAD (note: HARPS already corrects for movement of earth)
        """sub = np.where((wave > 6558.8) & (wave < 6566.8))
        find_min = np.argmin(flux[sub])
        sub_wave = wave[sub]
        find_wave_at_min = sub_wave[find_min]
        #print(find_wave_at_min)
        RV_conv = find_wave_at_min-6562.8
        #print(RV_conv)"""
        
        #THE FOLLOWING S INDEX IS BASED ON EQN 2 OF ASTUDILLO-DEFRU ET AL. 2017 (page 4)

        #fnding mean V continuum flux
        cont_3901 = 3901 + RV_conv_K
        V_idx_cont = np.where((wave > (cont_3901 - 10)) & (wave < (cont_3901 + 10)))
        V_sub_cont = flux[V_idx_cont]
        V_err_cont = np.std(V_sub_cont)
        V_mean_cont = np.mean(V_sub_cont)
                              
        #finding mean K line flux
        K_idx_wave = np.array(np.where((wave > (3934 - 1.09/.5 + RV_conv_K)) & (wave < (3934 + 1.09/.5 + RV_conv_K))))
        K_sub_flux = flux[K_idx_wave]
        K_err_flux = err[K_idx_wave] 
        K_mean_flux = np.mean(K_sub_flux)
                              
        #finding mean H line flux
        H_idx_wave = np.array(np.where((wave > (3968 - 1.09/.5 + RV_conv_H)) & (wave < (3968 + 1.09/.5 + RV_conv_H))))
        H_sub_flux = flux[H_idx_wave]
        H_err_flux = err[H_idx_wave] 
        H_mean_flux = np.mean(H_sub_flux)
                                      
        #finding mean R continuum flux                      
        cont_4001 = 4001 + RV_conv_H
        R_idx_cont = np.where(((wave > (cont_4001 - 10)) & (wave < (cont_4001 + 10))))
        R_sub_cont = flux[R_idx_cont]
        R_err_cont = np.std(R_sub_cont)
        R_mean_cont = np.mean(R_sub_cont)
                              
        #S INDEX!!!
        S_instrument_calibrated = (H_mean_flux + K_mean_flux) / (V_mean_cont + R_mean_cont)
        S = 1.053 * S_instrument_calibrated + 0.026
        
        if H_mean_flux < 0.0:
            print(spectra[i], " H flux negative: ", H_mean_flux)
        if K_mean_flux < 0.0:
            print(spectra[i], " K flux negative: ", K_mean_flux)
        if V_mean_cont < 0.0:
            print(spectra[i], " V flux negative: ", V_mean_cont)
        if R_mean_cont < 0.0:
            print(spectra[i], " R flux negative: ", R_mean_cont)
        
        #THE FOLLOWING R'HK INDEX IS BASED ON ASTUDILLO-DEFRU ET AL. 2017 EQNS 4, 9, 11, AND TABLE 1
        Rhk = 1.887e-4 * Ccf * S
        #print(Rhk)
        RHK_PRIME = Rhk - Rphot
        #print(RHK_PRIME)
        
        #COLLECTING INFO FOR ALL SPECTRA OF A SINGLE STAR
        all_S.append(S)
        all_RHK_PRIME.append(RHK_PRIME)
    
    #AVERAGING CALCULATED INDEX VALUES FOR EACH STAR
    stars_S_avgs.append(np.mean(all_S))
    stars_S_avgs_err.append(np.std(all_S, ddof=1))
    stars_RHK_PRIME_avgs.append(np.mean(all_RHK_PRIME))
    stars_RHK_PRIME_avgs_err.append(np.std(all_RHK_PRIME, ddof=1))

print("Star names: ", star_names)
print("S averages for each star: ", stars_S_avgs)
print("R'HK averages for each star: ", stars_RHK_PRIME_avgs)
print("log(R'HK) averages for each star: ", np.log10(stars_RHK_PRIME_avgs))

# %%
#Graph of my values versus Astudillo-Defru values of R'HK listed in VizieR
#IS THERE A WAY TO QUERY THIS FOR ALL OVERLAP BETWEEN THEIR SAMPLE AND OURS???
ad_rhk = np.array([-4.911, -5.776, -5.182, -5.496, -5.457, -5.523, -4.843, -5.754])
ad_rkh_err = np.array([0.22, 0.057, 0.122, 0.057, 0.062, 0.06, 0.173, 0.045])
my_rhk = np.array([-5.193, -5.979, -5.366, -5.592, -5.490, -5.609, -5.139, -5.977])

plt.scatter(my_rhk, ad_rhk)
plt.errorbar(my_rhk, ad_rhk, yerr=ad_rkh_err, linestyle="None")
plt.plot(np.linspace(-5,-6.2),np.linspace(-5,-6.2))
plt.title("Comparison of R'HK index results")
plt.xlabel("Melbourne $log(R'HK)$")
plt.ylabel("Astudio-Defru $log(R'HK)$")

#NEED MORE POINTS!!!
